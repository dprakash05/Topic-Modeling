# %%
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer
import pandas as pd
import re
import nltk
nltk.download('popular')
from nltk.tokenize import word_tokenize
from language_detector import detect_language

import pkg_resources
from symspellpy import SymSpell, Verbosity

sym_spell = SymSpell(max_dictionary_edit_distance=3, prefix_length=7)
dictionary_path = pkg_resources.resource_filename(
    "symspellpy", "frequency_dictionary_en_82_765.txt")
if sym_spell.word_count:
    pass
else:
    sym_spell.load_dictionary(dictionary_path, term_index=0, count_index=1)

# cohernece
from collections import Counter
from sklearn.metrics import silhouette_score
from gensim.models.coherencemodel import CoherenceModel    

# lda
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from gensim import corpora
import gensim
import numpy as np
from datetime import datetime

# autoencoder
import keras
from keras.layers import Input, Dense
from keras.models import Model
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Devdatta
# [nltk_data]    |     Supnekar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %% [markdown]
# ### Preprocessing

# %%
# preprocessing.py

###################################
#### sentence level preprocess ####
###################################

# lowercase + base filter
# some basic normalization
def f_base(s):
    """
    :param s: string to be processed
    :return: processed string: see comments in the source code for more info
    """
    # normalization 1: xxxThis is a --> xxx. This is a (missing delimiter)
    s = re.sub(r'([a-z])([A-Z])', r'\1\. \2', s)  # before lower case
    # normalization 2: lower case
    s = s.lower()
    # normalization 3: "&gt", "&lt"
    s = re.sub(r'&gt|&lt', ' ', s)
    # normalization 4: letter repetition (if more than 2)
    s = re.sub(r'([a-z])\1{2,}', r'\1', s)
    # normalization 5: non-word repetition (if more than 1)
    s = re.sub(r'([\W+])\1{1,}', r'\1', s)
    # normalization 6: string * as delimiter
    s = re.sub(r'\*|\W\*|\*\W', '. ', s)
    # normalization 7: stuff in parenthesis, assumed to be less informal
    s = re.sub(r'\(.*?\)', '. ', s)
    # normalization 8: xxx[?!]. -- > xxx.
    s = re.sub(r'\W+?\.', '.', s)
    # normalization 9: [.?!] --> [.?!] xxx
    s = re.sub(r'(\.|\?|!)(\w)', r'\1 \2', s)
    # normalization 10: ' ing ', noise text
    s = re.sub(r' ing ', ' ', s)
    # normalization 11: noise text
    s = re.sub(r'product received for free[.| ]', ' ', s)
    # normalization 12: phrase repetition
    s = re.sub(r'(.{2,}?)\1{1,}', r'\1', s)

    return s.strip()


# language detection
def f_lan(s):
    """
    :param s: string to be processed
    :return: boolean (s is English)
    """

    # some reviews are actually english but biased toward french
    return detect_language(s) in {'English', 'French','Spanish','Chinese'}


###############################
#### word level preprocess ####
###############################

# filtering out punctuations and numbers
def f_punct(w_list):
    """
    :param w_list: word list to be processed
    :return: w_list with punct and number filter out
    """
    return [word for word in w_list if word.isalpha()]


# selecting nouns
def f_noun(w_list):
    """
    :param w_list: word list to be processed
    :return: w_list with only nouns selected
    """
    return [word for (word, pos) in nltk.pos_tag(w_list) if pos[:2] == 'NN']


# typo correction
def f_typo(w_list):
    """
    :param w_list: word list to be processed
    :return: w_list with typo fixed by symspell. words with no match up will be dropped
    """
    w_list_fixed = []
    for word in w_list:
        suggestions = sym_spell.lookup(word, Verbosity.CLOSEST, max_edit_distance=3)
        if suggestions:
            w_list_fixed.append(suggestions[0].term)
        else:
            pass
            # do word segmentation, deprecated for inefficiency
            # w_seg = sym_spell.word_segmentation(phrase=word)
            # w_list_fixed.extend(w_seg.corrected_string.split())
    return w_list_fixed


# stemming if doing word-wise
p_stemmer = PorterStemmer()


def f_stem(w_list):
    """
    :param w_list: word list to be processed
    :return: w_list with stemming
    """
    return [p_stemmer.stem(word) for word in w_list]


# filtering out stop words
# create English stop words list

stop_words = (list(
    set(get_stop_words('en'))
    |set(get_stop_words('es'))
    |set(get_stop_words('de'))
    |set(get_stop_words('it'))
    |set(get_stop_words('ca'))
    #|set(get_stop_words('cy'))
    |set(get_stop_words('pt'))
    #|set(get_stop_words('tl'))
    |set(get_stop_words('pl'))
    #|set(get_stop_words('et'))
    |set(get_stop_words('da'))
    |set(get_stop_words('ru'))
    #|set(get_stop_words('so'))
    |set(get_stop_words('sv'))
    |set(get_stop_words('sk'))
    #|set(get_stop_words('cs'))
    |set(get_stop_words('nl'))
    #|set(get_stop_words('sl'))
    #|set(get_stop_words('no'))
    #|set(get_stop_words('zh-cn'))
))

def f_stopw(w_list):
    """
    filtering out stop words
    """
    return [word for word in w_list if word not in stop_words]


def preprocess_sent(rw):
    """
    Get sentence level preprocessed data from raw review texts
    :param rw: review to be processed
    :return: sentence level pre-processed review
    """
    s = f_base(rw)
    if not f_lan(s):
        return None
    return s


def preprocess_word(s):
    """
    Get word level preprocessed data from preprocessed sentences
    including: remove punctuation, select noun, fix typo, stem, stop_words
    :param s: sentence to be processed
    :return: word level pre-processed review
    """
    if not s:
        return None
    w_list = word_tokenize(s)
    w_list = f_punct(w_list)
    w_list = f_noun(w_list)
    w_list = f_typo(w_list)
    w_list = f_stem(w_list)
    w_list = f_stopw(w_list)

    return w_list

def preprocess(docs, samp_size=None):
    """
    Preprocess the data
    """
    if not samp_size:
        samp_size = 1000

    print('Preprocessing raw texts ...')
    n_docs = len(docs)
    sentences = []  # sentence level preprocessed
    token_lists = []  # word level preprocessed
    idx_in = []  # index of sample selected
    #     samp = list(range(100))
    samp = np.random.choice(n_docs, samp_size)
    for i, idx in enumerate(samp):
        sentence = preprocess_sent(docs[idx])
        token_list = preprocess_word(sentence)
        if token_list:
            idx_in.append(idx)
            sentences.append(sentence)
            token_lists.append(token_list)
        print('{} %'.format(str(np.round((i + 1) / len(samp) * 100, 2))), end='\r')
    print('Preprocessing raw texts. Done!')
    return sentences, token_lists, idx_in

# %% [markdown]
# ### Utuility

# %%
# utils.py

def get_topic_words(token_lists, labels, k=None):
    """
    get top words within each topic from clustering results
    """
    if k is None:
        k = len(np.unique(labels))
    topics = ['' for _ in range(k)]
    for i, c in enumerate(token_lists):
        topics[labels[i]] += (' ' + ' '.join(c))
    word_counts = list(map(lambda x: Counter(x.split()).items(), topics))
    # get sorted word counts
    word_counts = list(map(lambda x: sorted(x, key=lambda x: x[1], reverse=True), word_counts))
    # get topics
    topics = list(map(lambda x: list(map(lambda x: x[0], x[:10])), word_counts))
    return topics

def get_coherence(model, token_lists, measure='c_v'):
    """
    Get model coherence from gensim.models.coherencemodel
    :param model: Topic_Model object
    :param token_lists: token lists of docs
    :param topics: topics as top words
    :param measure: coherence metrics
    :return: coherence score
    """
    if model.method == 'LDA':
        cm = CoherenceModel(model=model.ldamodel, texts=token_lists, corpus=model.corpus, dictionary=model.dictionary,
                            coherence=measure)
    else:
        topics = get_topic_words(token_lists, model.cluster_model.labels_)
        cm = CoherenceModel(topics=topics, texts=token_lists, corpus=model.corpus, dictionary=model.dictionary,
                            coherence=measure)
    return cm.get_coherence()

def get_silhouette(model):
    """
    Get silhouette score from model
    :param model: Topic_Model object
    :return: silhouette score
    """
    if model.method == 'LDA':
        return
    lbs = model.cluster_model.labels_
    vec = model.vec[model.method]
    return silhouette_score(vec, lbs)

# %% [markdown]
# ### Autoencoder

# %%
class Autoencoder:
    """
    Autoencoder for learning latent space representation
    architecture simplified for only one hidden layer
    """

    def __init__(self, latent_dim=32, activation='relu', epochs=200, batch_size=128):
        self.latent_dim = latent_dim
        self.activation = activation
        self.epochs = epochs
        self.batch_size = batch_size
        self.autoencoder = None
        self.encoder = None
        self.decoder = None
        self.his = None

    def _compile(self, input_dim):
        """
        compile the computational graph
        """
        input_vec = Input(shape=(input_dim,))
        encoded = Dense(self.latent_dim, activation=self.activation)(input_vec)
        decoded = Dense(input_dim, activation=self.activation)(encoded)
        self.autoencoder = Model(input_vec, decoded)
        self.encoder = Model(input_vec, encoded)
        encoded_input = Input(shape=(self.latent_dim,))
        decoder_layer = self.autoencoder.layers[-1]
        self.decoder = Model(encoded_input, self.autoencoder.layers[-1](encoded_input))
        self.autoencoder.compile(optimizer='adam', loss=keras.losses.mean_squared_error)

    def fit(self, X):
        if not self.autoencoder:
            self._compile(X.shape[1])
        X_train, X_test = train_test_split(X)
        self.his = self.autoencoder.fit(X_train, X_train,
                                        epochs=self.epochs,
                                        batch_size=self.batch_size,
                                        shuffle=True,
                                        validation_data=(X_test, X_test), verbose=0)

# %% [markdown]
# ### BASE TM

# %%
### base tm


# define model object
class Topic_Model:
    def __init__(self, k=10, method='TFIDF'):
        """
        :param k: number of topics
        :param method: method chosen for the topic model
        """
        if method not in {'TFIDF', 'LDA', 'BERT', 'LDA_BERT'}:
            raise Exception('Invalid method!')
        self.k = k
        self.dictionary = None
        self.corpus = None
        #self.stopwords = None
        self.cluster_model = None
        self.ldamodel = None
        self.vec = {}
        self.gamma = 15  # parameter for relative importance of lda
        self.method = method
        self.AE = None
        self.id = method + '_' + datetime.now().strftime("%Y_%m_%d_%H_%M_%S")

    def vectorize(self, sentences, token_lists, method=None):
        """
        Get vector representations from selected methods
        """
        # Default method
        if method is None:
            method = self.method

        # turn tokenized documents into a id <-> term dictionary
        self.dictionary = corpora.Dictionary(token_lists)
        # convert tokenized documents into a document-term matrix
        self.corpus = [self.dictionary.doc2bow(text) for text in token_lists]

        if method == 'TFIDF':
            print('Getting vector representations for TF-IDF ...')
            tfidf = TfidfVectorizer()
            vec = tfidf.fit_transform(sentences)
            print('Getting vector representations for TF-IDF. Done!')
            return vec

        elif method == 'LDA':
            print('Getting vector representations for LDA ...')
            if not self.ldamodel:
                self.ldamodel = gensim.models.ldamodel.LdaModel(self.corpus, num_topics=self.k, id2word=self.dictionary,
                                                                passes=20)

            def get_vec_lda(model, corpus, k):
                """
                Get the LDA vector representation (probabilistic topic assignments for all documents)
                :return: vec_lda with dimension: (n_doc * n_topic)
                """
                n_doc = len(corpus)
                vec_lda = np.zeros((n_doc, k))
                for i in range(n_doc):
                    # get the distribution for the i-th document in corpus
                    for topic, prob in model.get_document_topics(corpus[i]):
                        vec_lda[i, topic] = prob

                return vec_lda

            vec = get_vec_lda(self.ldamodel, self.corpus, self.k)
            print('Getting vector representations for LDA. Done!')
            return vec

        elif method == 'BERT':

            print('Getting vector representations for BERT ...')
            from sentence_transformers import SentenceTransformer
            model = SentenceTransformer('bert-base-nli-max-tokens')
            vec = np.array(model.encode(sentences, show_progress_bar=True))
            print('Getting vector representations for BERT. Done!')
            return vec


        elif method == 'LDA_BERT':
            # else:
            vec_lda = self.vectorize(sentences, token_lists, method='LDA')
            vec_bert = self.vectorize(sentences, token_lists, method='BERT')
            vec_ldabert = np.c_[vec_lda * self.gamma, vec_bert]
            self.vec['LDA_BERT_FULL'] = vec_ldabert
            if not self.AE:
                self.AE = Autoencoder()
                print('Fitting Autoencoder ...')
                self.AE.fit(vec_ldabert)
                print('Fitting Autoencoder Done!')
            vec = self.AE.encoder.predict(vec_ldabert)
            return vec

    def fit(self, sentences, token_lists, method=None, m_clustering=None):
        """
        Fit the topic model for selected method given the preprocessed data
        :docs: list of documents, each doc is preprocessed as tokens
        :return:
        """
        # Default method
        if method is None:
            method = self.method
        # Default clustering method
        if m_clustering is None:
            m_clustering = KMeans

        # turn tokenized documents into a id <-> term dictionary
        if not self.dictionary:
            self.dictionary = corpora.Dictionary(token_lists)
            # convert tokenized documents into a document-term matrix
            self.corpus = [self.dictionary.doc2bow(text) for text in token_lists]

        ####################################################
        #### Getting ldamodel or vector representations ####
        ####################################################

        if method == 'LDA':
            if not self.ldamodel:
                print('Fitting LDA ...')
                self.ldamodel = gensim.models.ldamodel.LdaModel(self.corpus, num_topics=self.k, id2word=self.dictionary,
                                                                passes=20)
                print('Fitting LDA Done!')
        else:
            print('Clustering embeddings ...')
            self.cluster_model = m_clustering(self.k)
            self.vec[method] = self.vectorize(sentences, token_lists, method)
            self.cluster_model.fit(self.vec[method])
            print('Clustering embeddings. Done!')

    def predict(self, sentences, token_lists, out_of_sample=None):
        """
        Predict topics for new_documents
        """
        # Default as False
        out_of_sample = out_of_sample is not None

        if out_of_sample:
            corpus = [self.dictionary.doc2bow(text) for text in token_lists]
            if self.method != 'LDA':
                vec = self.vectorize(sentences, token_lists)
                print(vec)
        else:
            corpus = self.corpus
            vec = self.vec.get(self.method, None)

        if self.method == "LDA":
            lbs = np.array(list(map(lambda x: sorted(self.ldamodel.get_document_topics(x),
                                                     key=lambda x: x[1], reverse=True)[0][0],
                                    corpus)))
        else:
            lbs = self.cluster_model.predict(vec)
        return lbs

# %% [markdown]
# ### main

# %%
input_data_path = "data/bbc-text.csv"
method ='LDA_BERT'
ntopic = 10
save=True, 
output_data_path = "output/bbc-text_reviews.csv"

# %%
documents = pd.read_csv(input_data_path)
# keeping only the first two columns
documents = documents.iloc[:100, 0:2]

# %%
documents.head()
# Out:
#    index                                               text
# 0      1  tv future in the hands of viewers with home th...
# 1      2  worldcom boss  left books alone  former worldc...
# 2      3  tigers wary of farrell  gamble  leicester say ...
# 3      4  yeading face newcastle in fa cup premiership s...
# 4      5  ocean s twelve raids box office ocean s twelve...

# %%
documents.isna().sum()
# Out:
# index    0
# text     0
# dtype: int64

# %%
documents.dropna(inplace=True)
samp_size = len(documents)

# %%
samp_size
# Out:
# 100

# %%
print(documents.columns)
documents.columns = ['index', 'abstract']
print(documents.columns)
documents.abstract = documents.abstract.astype(str)
# Out:
# Index(['index', 'text'], dtype='object')
# Index(['index', 'abstract'], dtype='object')

# %%
rws = documents.abstract

# %%
rws[:2]
# Out:
# 0    tv future in the hands of viewers with home th...
# 1    worldcom boss  left books alone  former worldc...
# Name: abstract, dtype: object

# %%
sentences, token_lists, idx_in = preprocess(rws, samp_size=samp_size)
# Out:
# Preprocessing raw texts ...
# Preprocessing raw texts. Done!

# %%
print(sentences[0])
print()
print(token_lists[0])
print()
print(idx_in[0])
# Out:
# labour targets hardcore truants a fresh crackdown on persistent truants in england has been launched by education secretary ruth kelly. serial truants make up one in 13 pupils. previous initiatives brought 40 000 pupils back to school since 1997 according to official statistics. parenting contracts penalty notices and fast track prosecution systems have been used to tackle what has been a stubborn problem. it is thought that nearly half a million children skip school each day. tories say labour s previous success regarding the issue came because it tackled the easy part of the problem by reducing authorised absence where parents are permitted to take children out of school. such absences are often due to family holidays. however serial truants avoid the classroom despite government schemes costing ? 885m. those missing classes are more likely to become involved in crime as well as failing academically. measures such as parenting contracts and penalty notices were adopted by most local education authorities last term and come into force in the remainder this term. in one local education authority alone 800 parents were warned they would receive a penalty notice unless their child s attendance improved. the tough stance paid off with just 24 issued while attendance improved in 776 cases. truancy has been reduced by 5% at the 128 worst hit schools through the government s behaviour improvement programme. this the equivalent of 200 pupils back in classes since september. the new measures come on top of national truancy sweeps - the sixth of which will take place on monday. police and education welfare officers patrol problem hotspots picking up truants and returning them to school. held twice each year in addition to routine local patrols previous country-wide sweeps have apprehended 31 000 pupils dodging school. in almost 14 000 of those cases the youngsters were accompanied by their parents. a department for education and skills source said: every day in school counts. it is clear form these figures that schools and local education authorities are now seizing the tools we have given them to improve school attendance and crack down hard on the very small numbers of pupils which account for almost half of the nation s truancy.
#
# ['target', 'truant', 'crackdown', 'truant', 'england', 'educ', 'secretari', 'ruth', 'truant', 'pupil', 'initi', 'pupil', 'school', 'statist', 'contract', 'penalti', 'notic', 'track', 'prosecut', 'system', 'problem', 'children', 'school', 'day', 'tori', 'success', 'issu', 'part', 'problem', 'absenc', 'parent', 'children', 'school', 'absenc', 'famili', 'holiday', 'truant', 'classroom', 'govern', 'scheme', 'class', 'crime', 'measur', 'contract', 'penalti', 'notic', 'educ', 'author', 'term', 'forc', 'remaind', 'term', 'educ', 'author', 'parent', 'penalti', 'notic', 'child', 'attend', 'stanc', 'attend', 'case', 'truanci', 'hit', 'school', 'govern', 'improv', 'programm', 'equival', 'pupil', 'class', 'measur', 'top', 'truanci', 'sixth', 'place', 'polic', 'educ', 'welfar', 'offic', 'problem', 'hotshot', 'truant', 'school', 'year', 'addit', 'patrol', 'sweep', 'pupil', 'school', 'case', 'youngster', 'parent', 'depart', 'educ', 'skill', 'sourc', 'day', 'school', 'count', 'figur', 'school', 'educ', 'author', 'tool', 'school', 'attend', 'number', 'pupil', 'half', 'nation', 'truanci']
#
# 40

# %%
 tm = Topic_Model(k=ntopic, method=method)

# %%
# Fit the topic model by chosen method
tm.fit(sentences, token_lists)
# Out:
# Clustering embeddings ...
# Getting vector representations for LDA ...
# Getting vector representations for LDA. Done!
# Getting vector representations for BERT ...
# Batches: 100%|█████████████████████████████████████████████████████████████████████████| 13/13 [00:25<00:00,  1.97s/it]
# Getting vector representations for BERT. Done!
# Fitting Autoencoder ...
# WARNING:tensorflow:From C:\Anaconda\envs\context_tm\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# WARNING:tensorflow:From C:\Anaconda\envs\context_tm\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Fitting Autoencoder Done!
# Clustering embeddings. Done!

# %%
print(tm.k)
# Out:
# 10

# %%
print(tm.cluster_model)
# Out:
# KMeans(n_clusters=10)

# %%
print(tm.method)
# Out:
# LDA_BERT

# %%
print(tm.ldamodel)
# Out:
# LdaModel(num_terms=1957, num_topics=10, decay=0.5, chunksize=2000)

# %%
print(tm.corpus[0])
# Out:
# [(0, 2), (1, 1), (2, 3), (3, 3), (4, 2), (5, 1), (6, 2), (7, 2), (8, 1), (9, 2), (10, 1), (11, 1), (12, 1), (13, 2), (14, 1), (15, 6), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 2), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 2), (30, 1), (31, 3), (32, 1), (33, 1), (34, 3), (35, 1), (36, 1), (37, 3), (38, 1), (39, 1), (40, 3), (41, 1), (42, 1), (43, 5), (44, 1), (45, 1), (46, 1), (47, 9), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 2), (59, 1), (60, 1), (61, 1), (62, 1), (63, 3), (64, 5), (65, 1), (66, 1), (67, 1)]

# %%
def get_vec_lda(model, corpus, k):
    """
    Get the LDA vector representation (probabilistic topic assignments for all documents)
    :return: vec_lda with dimension: (n_doc * n_topic)
    """
    n_doc = len(corpus)
    vec_lda = np.zeros((n_doc, k))
    for i in range(n_doc):
        # get the distribution for the i-th document in corpus
        for topic, prob in model.get_document_topics(corpus[i]):
            vec_lda[i, topic] = prob

    return vec_lda

# %%
lda_vec = get_vec_lda(tm.ldamodel, tm.corpus, tm.k)
print('Getting vector representations for LDA. Done!')
# Out:
# Getting vector representations for LDA. Done!

# %%
lda_vec[0]
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.99203366, 0.        , 0.        ])

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-max-tokens')
bert_vec  = np.array(model.encode(sentences, show_progress_bar=True))
# Out:
# Batches: 100%|█████████████████████████████████████████████████████████████████████████| 13/13 [00:24<00:00,  1.89s/it]

# %%
len(bert_vec[2])
# Out:
# 768

# %%
bert_vec[0]
# Out:
# array([ 1.61987841e-01,  6.14772618e-01,  7.95406044e-01,  2.89551347e-01,
#         4.30810064e-01,  3.85483772e-01,  1.79240155e+00,  4.46105599e-01,
#         9.03564095e-01,  2.38364935e-01,  5.34198403e-01,  5.93950748e-01,
#         1.26073563e+00,  2.42247999e-01, -9.56908166e-02,  3.09282899e-01,
#         1.45288455e+00,  6.46177351e-01,  6.98070168e-01,  6.96181595e-01,
#         5.99174261e-01, -1.50477827e-01,  1.62503028e+00,  8.16035628e-01,
#         2.07537675e+00,  1.52503550e+00,  7.04982162e-01,  1.07531130e+00,
#         1.99210346e-01,  1.08706087e-01,  3.83886695e-01,  1.38526356e+00,
#         7.06467927e-01,  9.07281339e-01,  1.74387181e+00,  1.10470212e+00,
#         5.97168744e-01,  5.31288207e-01,  8.49426985e-01,  2.58426331e-02,
#         1.86572206e+00,  4.22031850e-01, -1.29834026e-01, -3.32735777e-01,
#         4.11015689e-01, -2.63165627e-02,  1.07907951e-02,  1.12351251e+00,
#         9.35332000e-01,  2.25399375e-01,  3.45867909e-02,  1.51082242e+00,
#         1.39099312e+00, -2.04376370e-01,  8.63774940e-02,  5.52619159e-01,
#         6.98561907e-01, -6.06646948e-02,  7.37400725e-02, -1.25934094e-01,
#         3.25913846e-01,  1.60956395e+00,  7.06149936e-01,  3.70366484e-01,
#         6.55737698e-01,  9.00162220e-01,  1.03095949e+00,  2.00712705e+00,
#        -1.19842842e-01, -6.60487652e-01, -1.16331026e-01,  2.12183390e-02,
#         1.20631933e-01,  1.00329302e-01,  1.04988885e+00,  2.95833409e-01,
#         5.01526535e-01,  7.85136819e-01,  2.26473331e+00,  1.42798483e+00,
#         1.39203906e+00,  4.04608548e-01,  1.17553306e+00,  1.19830683e-01,
#         1.24387991e+00,  1.09597325e+00,  1.58575559e+00,  1.05354774e+00,
#         1.49330688e+00,  1.20069146e+00,  1.72327101e+00,  8.43773007e-01,
# Out:
# dict_keys(['LDA_BERT_FULL', 'LDA_BERT'])

# %%
len(tm.vec["LDA_BERT_FULL"][0])
# Out:
# 778

# %%
# autoencoder output
len(tm.vec["LDA_BERT"][0])
# Out:
# 32

# %%
len(tm.vec["LDA_BERT"])
# Out:
# 100

# %%
tm.vec["LDA_BERT"][0]
# Out:
# array([3.453227 , 0.       , 7.9297504, 4.522833 , 0.       , 2.7703547,
#        3.0376356, 5.244283 , 3.9629917, 5.554574 , 1.8028933, 1.9948114,
#        5.202819 , 0.       , 4.646662 , 0.       , 0.       , 2.657138 ,
#        2.3739424, 0.       , 0.       , 5.9313416, 0.       , 2.3671377,
#        3.8265424, 2.8723917, 8.546598 , 3.8753705, 2.2664616, 0.       ,
#        4.145443 , 2.8545773], dtype=float32)

# %%
tm.method
# Out:
# 'LDA_BERT'

# %%
 # Evaluate using metrics
if tm.method == "LDA":
    topics = []
    for topic in tm.ldamodel.print_topics(num_topics=tm.ntopic):
        topic_list = [re.search(r"[a-zA-z]+", w).group(0) for w in topic[1].split('+')]
        topics.append(topic_list)
else:
    topics = get_topic_words(token_lists, tm.cluster_model.labels_)

# %%
topics
# Out:
# [['year',
#   'govern',
#   'film',
#   'life',
#   'club',
#   'music',
#   'share',
#   'parti',
#   'money',
#   'drug'],
#  ['technolog',
#   'network',
#   'panda',
#   'sound',
#   'audio',
#   'phone',
#   'world',
#   'research',
#   'game',
#   'reserv'],
#  ['peopl',
#   'law',
#   'terror',
#   'power',
#   'right',
#   'blog',
#   'clark',
#   'hous',
#   'evid',
#   'viru'],
#  ['game',
#   'ireland',
#   'england',
#   'tri',
#   'ball',
#   'compani',
#   'jersey',
#   'coach',
#   'way',
#   'refere'],
#  ['price',
#   'growth',
#   'quarter',
#   'year',
#   'economi',
#   'number',
#   'sequel',
#   'singapor',
#   'hous',
#   'effect'],
#  ['peopl',
#   'film',
#   'ranger',
#   'gorg',
#   'project',
#   'children',
#   'wale',
#   'health',
#   'ferguson',
#   'construct'],
#  ['player',
#   'coach',
#   'connor',
#   'relationship',
#   'kid',
#   'week',
#   'wilkinson',
#   'number',
#   'jimmi',
#   'practic'],
#  ['break',
#   'robinson',
#   'leagu',
#   'dodgson',
#   'england',
#   'winter',
#   'player',
#   'australia',
#   'britain',
#   'premiership'],
#  ['parti',
#   'answer',
#   'lord',
#   'hagu',
#   'goldsmith',
#   'advic',
#   'peopl',
#   'attorney',
#   'call',
#   'rule'],
#  ['telegraph',
#   'journalist',
#   'news',
#   'newspap',
#   'condor',
#   'group',
#   'print',
#   'compani',
#   'corp',
#   'share']]

# %%
tm.cluster_model.labels_
# Out:
# array([0, 3, 3, 5, 0, 4, 1, 0, 6, 3, 4, 8, 0, 0, 4, 0, 7, 0, 1, 3, 7, 0,
#        0, 3, 9, 9, 6, 5, 2, 2, 0, 1, 0, 0, 1, 4, 4, 6, 0, 0, 4, 3, 4, 6,
#        2, 2, 0, 2, 3, 5, 4, 5, 4, 6, 0, 3, 0, 5, 9, 7, 8, 6, 0, 6, 7, 8,
#        7, 0, 3, 8, 0, 5, 4, 5, 0, 2, 5, 0, 1, 5, 9, 0, 0, 0, 6, 0, 1, 9,
#        1, 0, 2, 9, 7, 5, 5, 2, 7, 0, 8, 8])

# %%
len(tm.cluster_model.labels_)
# Out:
# 100

# %%
def get_topic_words(token_lists, labels, k=None):
    """
    get top words within each topic from clustering results
    """
    if k is None:
        k = len(np.unique(labels))
    topics = ['' for _ in range(k)]
    for i, c in enumerate(token_lists):
        topics[labels[i]] += (' ' + ' '.join(c))
    word_counts = list(map(lambda x: Counter(x.split()).items(), topics))
    # get sorted word counts
    word_counts = list(map(lambda x: sorted(x, key=lambda x: x[1], reverse=True), word_counts))
    # get topics
    topics = list(map(lambda x: list(map(lambda x: x[0], x[:10])), word_counts))
    return topics

# %%
k = len(np.unique(tm.cluster_model.labels_))
print(k)
# Out:
# 10

# %%
a = ['' for _ in range(k)]

# %%
a
# Out:
# ['', '', '', '', '', '', '', '', '', '']

# %%
token_lists[:2]
# Out:
# [['target',
#   'truant',
#   'crackdown',
#   'truant',
#   'england',
#   'educ',
#   'secretari',
#   'ruth',
#   'truant',
#   'pupil',
#   'initi',
#   'pupil',
#   'school',
#   'statist',
#   'contract',
#   'penalti',
#   'notic',
#   'track',
#   'prosecut',
#   'system',
#   'problem',
#   'children',
#   'school',
#   'day',
#   'tori',
#   'success',
#   'issu',
#   'part',
#   'problem',
#   'absenc',
#   'parent',
#   'children',
#   'school',
#   'absenc',
#   'famili',
#   'holiday',
#   'truant',
#   'classroom',
#   'govern',
#   'scheme',
#   'class',
#   'crime',
#   'measur',
#   'contract',
#   'penalti',
#   'notic',
#   'educ',
#   'author',
#   'term',
#   'forc',
#   'remaind',
#   'term',
#   'educ',
#   'author',
#   'parent',
#   'penalti',
#   'notic',
#   'child',
#   'attend',
#   'stanc',
#   'attend',
#   'case',
#   'truanci',
#   'hit',
#   'school',
#   'govern',
#   'improv',
#   'programm',
#   'equival',
#   'pupil',
#   'class',
#   'measur',
#   'top',
#   'truanci',
#   'sixth',
#   'place',
#   'polic',
#   'educ',
#   'welfar',
#   'offic',
#   'problem',
#   'hotshot',
#   'truant',
#   'school',
#   'year',
#   'addit',
#   'patrol',
#   'sweep',
#   'pupil',
#   'school',
#   'case',
#   'youngster',
#   'parent',
#   'depart',
#   'educ',
#   'skill',
#   'sourc',
#   'day',
#   'school',
#   'count',
#   'figur',
#   'school',
#   'educ',
#   'author',
#   'tool',
#   'school',
#   'attend',
#   'number',
#   'pupil',
#   'half',
#   'nation',
#   'truanci'],
#  ['ireland',
#   'win',
#   'error',
#   'rugbi',
#   'board',
#   'coach',
#   'player',
#   'refere',
#   'thing',
#   'way',
#   'camera',
#   'field',
#   'perpetr',
#   'knuckl',
#   'ira',
#   'footbal',
#   'scenario',
#   'slang',
#   'match',
#   'game',
#   'nation',
#   'landown',
#   'road',
#   'exampl',
#   'ireland',
#   'step',
#   'slam',
#   'game',
#   'side',
#   'decis',
#   'way',
#   'frustrat',
#   'doubt',
#   'ireland',
#   'rub',
#   'green',
#   'victori',
#   'reaction',
#   'england',
#   'camp',
#   'sport',
#   'blazer',
#   'jonathan',
#   'plan',
#   'mean',
#   'decis',
#   'villain',
#   'piec',
#   'plan',
#   'comment',
#   'recours',
#   'critic',
#   'simon',
#   'judg',
#   'scotland',
#   'coach',
#   'matt',
#   'william',
#   'defeat',
#   'franc',
#   'england',
#   'queri',
#   'mark',
#   'auto',
#   'corner',
#   'charli',
#   'dodgson',
#   'kick',
#   'england',
#   'coach',
#   'robinson',
#   'case',
#   'raven',
#   'ulster',
#   'gloucest',
#   'cup',
#   'occas',
#   'humphrey',
#   'bowl',
#   'corner',
#   'tri',
#   'camera',
#   'angl',
#   'anomali',
#   'robinson',
#   'refere',
#   'josh',
#   'jersey',
#   'line',
#   'jersey',
#   'claim',
#   'control',
#   'credit',
#   'ireland',
#   'flanker',
#   'johnni',
#   'ball',
#   'evid',
#   'rugbi',
#   'everyth',
#   'minut',
#   'refere',
#   'england',
#   'greenock',
#   'ball',
#   'martin',
#   'sorri',
#   'stroll',
#   'line',
#   'moment',
#   'game',
#   'foe',
#   'bristol',
#   'tri',
#   'charli',
#   'kick',
#   'display',
#   'highlight',
#   'roman',
#   'gari',
#   'abil',
#   'game',
#   'compon',
#   'defin',
#   'moment',
#   'ireland',
#   'cosh',
#   'minut',
#   'piec',
#   'play',
#   'england',
#   'ireland',
#   'vicki',
#   'brilliant',
#   'tackl',
#   'corner',
#   'auto',
#   'dodgson',
#   'kick',
#   'feet',
#   'jersey',
#   'tri',
#   'ireland',
#   'colossu',
#   'paul',
#   'cornel',
#   'england',
#   'way',
#   'defenc',
#   'cordon',
#   'prop',
#   'matt',
#   'ran',
#   'steam',
#   'tackler',
#   'cornel',
#   'ball',
#   'turnov',
#   'volum',
#   'ireland',
#   'coach',
#   'mike',
#   'ford',
#   'bow',
#   'game',
#   'ireland',
#   'tri',
#   'game',
#   'defenc',
#   'championship']]

# %%
a = ['' for _ in range(k)]
for i, c in enumerate(token_lists):
        a[tm.cluster_model.labels_[i]] += (' ' + ' '.join(c))

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 10

# %%
word_counts = list(map(lambda x: Counter(x.split()).items(), a))

# %%
word_counts
# Out:
# [dict_items([('target', 1), ('truant', 5), ('crackdown', 1), ('england', 4), ('educ', 10), ('secretari', 4), ('ruth', 1), ('pupil', 5), ('initi', 1), ('school', 13), ('statist', 1), ('contract', 2), ('penalti', 3), ('notic', 3), ('track', 1), ('prosecut', 1), ('system', 4), ('problem', 12), ('children', 3), ('day', 7), ('tori', 2), ('success', 8), ('issu', 2), ('part', 16), ('absenc', 2), ('parent', 5), ('famili', 6), ('holiday', 1), ('classroom', 1), ('govern', 37), ('scheme', 3), ('class', 4), ('crime', 2), ('measur', 4), ('author', 4), ('term', 9), ('forc', 2), ('remaind', 1), ('child', 4), ('attend', 3), ('stanc', 2), ('case', 7), ('truanci', 3), ('hit', 3), ('improv', 1), ('programm', 5), ('equival', 1), ('top', 6), ('sixth', 1), ('place', 7), ('polic', 1), ('welfar', 1), ('offic', 4), ('hotshot', 1), ('year', 40), ('addit', 4), ('patrol', 2), ('sweep', 1), ('youngster', 1), ('depart', 2), ('skill', 1), ('sourc', 1), ('count', 1), ('figur', 5), ('tool', 1), ('number', 7), ('half', 3), ('nation', 3), ('bate', 12), ('seal', 2), ('takeov', 14), ('leed', 12), ('chelsea', 8), ('chairman', 7), ('deal', 13), ('get', 2), ('friday', 2), ('stake', 12), ('club', 26), ('mantel', 2), ('time', 15), ('lot', 3), ('work', 5), ('premiership', 4), ('help', 6), ('everyth', 4), ('guis', 2), ('compani', 19), ('forward', 3), ('sport', 4), ('fund', 15), ('plan', 7), ('leland', 2), ('road', 3), ('stadium', 2), ('thorp', 2), ('arch', 2), ('ground', 2), ('cours', 5), ('jon', 2), ('task', 2), ('cash', 4), ('flow', 2), ('sort', 2), ('creditor', 2), ('light', 4), ('tunnel', 2), ('matter', 2), ('gerald', 2), ('trainer', 6), ('medium', 2), ('surviv', 2), ('propos', 7), ('benefit', 6), ('march', 4), ('debt', 5), ('date', 2), ('board', 9), ('percent', 2), ('agreement', 2), ('consortium', 2), ('background', 2), ('period', 4), ('smooth', 2), ('capac', 4), ('peter', 8), ('lorim', 4), ('role', 6), ('director', 12), ('point', 6), ('contact', 2), ('mccormick', 2), ('consult', 2), ('loan', 2), ('financ', 7), ('yvonn', 2), ('todd', 2), ('lawyer', 2), ('mark', 2), ('taylor', 2), ('detail', 2), ('money', 20), ('month', 9), ('chequ', 3), ('week', 11), ('person', 2), ('discuss', 3), ('arrang', 4), ('roman', 2), ('stamford', 2), ('bridg', 2), ('wednesday', 3), ('salisburi', 2), ('offer', 6), ('effort', 6), ('brink', 2), ('administr', 4), ('deduct', 2), ('footbal', 3), ('leagu', 6), ('invest', 19), ('prospect', 2), ('power', 12), ('share', 24), ('debut', 9), ('produc', 5), ('stock', 16), ('market', 19), ('pc', 2), ('firm', 18), ('mix', 2), ('sale', 9), ('rupe', 2), ('flotat', 4), ('softwar', 2), ('bet', 2), ('analyst', 10), ('need', 8), ('india', 4), ('countri', 11), ('economi', 2), ('util', 2), ('world', 9), ('debat', 3), ('donat', 8), ('cap', 4), ('parti', 21), ('elect', 12), ('watchdog', 2), ('fear', 1), ('donor', 3), ('favour', 1), ('call', 3), ('limit', 3), ('report', 8), ('commiss', 5), ('futur', 3), ('state', 8), ('candid', 3), ('campaign', 3), ('gift', 2), ('rule', 2), ('public', 4), ('suspicion', 1), ('taxpay', 3), ('someth', 4), ('principl', 2), ('introduct', 1), ('departur', 1), ('amount', 3), ('differ', 3), ('chang', 2), ('incom', 1), ('tax', 6), ('relief', 2), ('member', 1), ('hous', 1), ('common', 2), ('parliament', 2), ('welsh', 1), ('assembl', 2), ('ireland', 2), ('way', 9), ('voter', 3), ('mailshot', 1), ('leaflet', 1), ('shift', 1), ('level', 8), ('politician', 4), ('spend', 3), ('poll', 1), ('happen', 1), ('younger', 1), ('doubt', 1), ('health', 4), ('democraci', 1), ('research', 5), ('peopl', 18), ('polit', 2), ('consensu', 1), ('seed', 8), ('tim', 2), ('herman', 11), ('set', 8), ('dubai', 4), ('ivan', 3), ('victori', 3), ('match', 9), ('progress', 2), ('rain', 4), ('break', 4), ('win', 2), ('fifth', 2), ('tommi', 2), ('roberto', 2), ('liefer', 2), ('germani', 2), ('afterward', 2), ('weather', 3), ('umpir', 2), ('doe', 2), ('control', 4), ('game', 7), ('score', 2), ('irrelev', 2), ('form', 3), ('desert', 2), ('scott', 3), ('start', 4), ('allan', 1), ...
#  dict_items([('panda', 28), ('world', 20), ('popul', 8), ('hand', 4), ('wireless', 12), ('internet', 4), ('network', 30), ('natur', 8), ('reserv', 16), ('provinc', 4), ('china', 4), ('broadband', 4), ('staff', 12), ('activ', 4), ('data', 8), ('imag', 4), ('colleagu', 4), ('research', 18), ('breed', 4), ('bamboo', 4), ('ecolog', 4), ('vet', 4), ('feed', 4), ('suggest', 4), ('chang', 4), ('cub', 4), ('chanc', 4), ('technolog', 51), ('way', 4), ('share', 4), ('inform', 7), ('long', 8), ('rest', 4), ('hang', 4), ('director', 10), ('surround', 7), ('intel', 4), ('video', 4), ('monitor', 4), ('system', 7), ('camera', 4), ('clock', 4), ('infrastructur', 4), ('park', 4), ('disk', 4), ('health', 4), ('paper', 4), ('notebook', 4), ('team', 4), ('field', 7), ('access', 4), ('link', 4), ('globe', 4), ('children', 8), ('lab', 4), ('collabor', 4), ('globin', 4), ('organis', 4), ('primari', 4), ('school', 4), ('peer', 4), ('portland', 4), ('oregon', 4), ('stori', 4), ('life', 4), ('dialogu', 4), ('bridg', 4), ('cultur', 4), ('founder', 4), ('gerri', 4), ('elli', 4), ('audio', 21), ('enter', 3), ('dimens', 3), ('phone', 21), ('media', 6), ('player', 3), ('devic', 6), ('sound', 27), ('buzz', 3), ('bee', 3), ('jump', 3), ('back', 3), ('head', 6), ('demo', 3), ('heard', 3), ('home', 3), ('cinema', 3), ('firm', 9), ('synapt', 3), ('number', 3), ('compani', 12), ('speaker', 3), ('offer', 3), ('david', 3), ('monteith', 9), ('mobil', 3), ('bit', 9), ('nicer', 3), ('channel', 3), ('doom', 3), ('standard', 3), ('month', 6), ('handset', 12), ('fujitsu', 3), ('mitsubishi', 3), ('marker', 3), ('chip', 6), ('yamaha', 3), ('room', 3), ('pc', 3), ('game', 18), ('consol', 3), ('time', 3), ('consum', 3), ('scienc', 3), ('sinbad', 3), ('ear', 12), ('area', 3), ('brain', 6), ('structur', 3), ('encod', 3), ('understand', 3), ('process', 6), ('mic', 3), ('impress', 3), ('left', 3), ('right', 6), ('listen', 3), ('fact', 3), ('sourc', 3), ('side', 3), ('shape', 3), ('caus', 3), ('differ', 6), ('impact', 6), ('market', 9), ('music', 6), ('download', 3), ('handheld', 3), ('limit', 3), ('screen', 3), ('definit', 3), ('movi', 3), ('fish', 3), ('titl', 3), ('gamer', 3), ('shoot', 3), ('pm', 3), ('develop', 3), ('song', 3), ('feel', 3), ('softwar', 3), ('version', 3), ('effici', 3), ('processor', 3), ('danon', 3), ('japan', 6), ('place', 3), ('us', 3)]),
', 1), ('kremlin', 1), ('head', 1), ('bill', 2), ('fine', 1), ('russia', 2), ('sale', 1), ('illeg', 1), ('busi', 2), ('mean', 1), ('dispos', 1), ('asset', 1), ('month', 7), ('analyst', 1), ('jurisdict', 1), ('moscow', 1), ('offici', 1), ('wrangl', 1), ('meaningless', 1), ('leta', 1), ('hear', 1), ('argument', 1), ('forum', 1), ('action', 1), ('file', 1), ('effect', 1), ('battl', 1), ('approx', 2), ('withdrew', 1), ('financ', 1), ('day', 1), ('robert', 2), ('meanwhil', 1), ('chunk', 1), ('claim', 1), ('sharehold', 1), ('founder', 1), ('mikhail', 1), ('richest', 1), ('fraud', 3), ('evas', 1), ('bail', 1), ('blog', 12), ('bug', 2), ('softwar', 2), ('microsoft', 2), ('plung', 2), ('world', 2), ('test', 2), ('servic', 8), ('journal', 6), ('space', 4), ('competitor', 4), ('googl', 4), ('log', 2), ('opinion', 2), ('hobnail', 2), ('messeng', 2), ('account', 4), ('layout', 2), ('page', 2), ('imag', 2), ('share', 2), ('photo', 2), ('album', 2), ('music', 2), ('banner', 2), ('tool', 2), ('web', 2), ('phenomenon', 2), ('blogger', 2), ('site', 2), ('member', 2), ('figur', 2), ('number', 4), ('exist', 4), ('analysi', 2), ('biospher', 2), ('quarter', 2), ('warn', 2), ('viru' ...
#  dict_items([('ireland', 27), ('win', 4), ('error', 3), ('rugbi', 6), ('board', 3), ('coach', 12), ('player', 7), ('refere', 11), ('thing', 3), ('way', 12), ('camera', 6), ('field', 3), ('perpetr', 3), ('knuckl', 3), ('ira', 3), ('footbal', 3), ('scenario', 3), ('slang', 3), ('match', 5), ('game', 29), ('nation', 5), ('landown', 3), ('road', 3), ('exampl', 3), ('step', 3), ('slam', 3), ('side', 5), ('decis', 10), ('frustrat', 3), ('doubt', 5), ('rub', 3), ('green', 3), ('victori', 3), ('reaction', 3), ('england', 20), ('camp', 3), ('sport', 5), ('blazer', 3), ('jonathan', 5), ('plan', 10), ('mean', 3), ('villain', 3), ('piec', 6), ('comment', 3), ('recours', 3), ('critic', 3), ('simon', 3), ('judg', 3), ('scotland', 3), ('matt', 6), ('william', 3), ('defeat', 3), ('franc', 3), ('queri', 3), ('mark', 5), ('auto', 10), ('corner', 9), ('charli', 6), ('dodgson', 8), ('kick', 11), ('robinson', 6), ('case', 3), ('raven', 3), ('ulster', 3), ('gloucest', 3), ('cup', 3), ('occas', 3), ('humphrey', 3), ('bowl', 3), ('tri', 20), ('angl', 3), ('anomali', 3), ('josh', 3), ('jersey', 15), ('line', 11), ('claim', 3), ('control', 3), ('credit', 3), ('flanker', 3), ('johnni', 3), ('ball', 19), ('evid', 3), ('everyth', 3), ('minut', 6), ('greenock', 3), ('martin', 3), ('sorri', 3), ('stroll', 3), ('moment', 6), ('foe', 3), ('bristol', 3), ('display', 3), ('highlight', 3), ('roman', 3), ('gari', 3), ('abil', 3), ('compon', 3), ('defin', 3), ('cosh', 3), ('play', 3), ('vicki', 3), ('brilliant', 3), ('tackl', 3), ('feet', 3), ('colossu', 3), ('paul', 3), ('
# %%
word_counts = list(map(lambda x: sorted(x, key=lambda x: x[1], reverse=True), word_counts))
word_counts
# Out:
# [[('year', 40),
#   ('govern', 37),
#   ('film', 36),
#   ('life', 27),
#   ('club', 26),
#   ('music', 26),
#   ('share', 24),
#   ('parti', 21),
#   ('money', 20),
#   ('drug', 20),
#   ('compani', 19),
#   ('invest', 19),
#   ('market', 19),
#   ('firm', 18),
#   ('peopl', 18),
#   ('sioux', 18),
#   ('part', 16),
#   ('stock', 16),
#   ('time', 15),
#   ('fund', 15),
#   ('award', 15),
#   ('polici', 15),
#   ('takeov', 14),
#   ('pm', 14),
#   ('school', 13),
#   ('deal', 13),
#   ('heart', 13),
#   ('rate', 13),
#   ('problem', 12),
#   ('bate', 12),
#   ('leed', 12),
#   ('stake', 12),
#   ('director', 12),
#   ('power', 12),
#   ('elect', 12),
#   ('risk', 12),
#   ('side', 12),
#   ('week', 11),
#   ('countri', 11),
#   ('herman', 11),
#   ('howard', 11),
#   ('educ', 10),
#   ('analyst', 10),
#   ('car', 10),
#   ('merck', 10),
#   ('term', 9),
#   ('board', 9),
#   ('month', 9),
#   ('debut', 9),
#   ('sale', 9),
#   ('world', 9),
#   ('way', 9),
#   ('match', 9),
#   ('pension', 9),
#   ('festiv', 9),
#   ('success', 8),
#   ('chelsea', 8),
#   ('peter', 8),
#   ('need', 8),
#   ('donat', 8),
#   ('report', 8),
#   ('state', 8),
#   ('level', 8),
#   ('seed', 8),
#   ('set', 8),
#   ('leader', 8),
#   ('sector', 8),
#   ('fiat', 8),
#   ('cut', 8),
#   ('job', 8),
#   ('cup', 8),
#   ('thursday', 8),
#   ('insur', 8),
#   ('bonu', 8),
#   ('inhibitor', 8),
#   ('patient', 8),
#   ('day', 7),
#   ('case', 7),
#   ('place', 7),
#   ('number', 7),
#   ('chairman', 7),
#   ('plan', 7),
#   ('propos', 7),
#   ('financ', 7),
#   ('game', 7),
#   ('soprano', 7),
#   ('musician', 7),
#   ('everyon', 7),
#   ('loss', 7),
#   ('commit', 7),
#   ('critic', 7),
#   ('famili', 6),
#   ('top', 6),
#   ('help', 6),
#   ('trainer', 6),
#   ('benefit', 6),
#   ('role', 6),
#   ('point', 6),
#   ('offer', 6),
#   ('effort', 6),
#   ('leagu', 6),
#   ('tax', 6),
#   ('record', 6),
#   ('prize', 6),
#   ('perform', 6),
#   ('industri', 6),
#   ('face', 6),
#   ('draw', 6),
#   ('manufactur', 6),
#   ('submiss', 6),
#   ('screen', 6),
#   ('fewer', 6),
#   ('bonus', 6),
#   ('policyhold', 6),
#   ('regul', 6),
#   ('painkil', 6),
#   ('attack', 6),
#   ('truant', 5),
#   ('pupil', 5),
#   ('parent', 5),
#   ('programm', 5),
#   ('figur', 5),
#   ('work', 5),
#   ('cours', 5),
#   ('debt', 5),
#   ('produc', 5),
#   ('commiss', 5),
#   ('research', 5),
#   ('race', 5),
#   ('group', 5),
#   ('servic', 5),
#   ('talent', 5),
#   ('thing', 5),
#   ('pop', 5),
#   ('right', 5),
#   ('product', 5),
#   ('confer', 5),
#   ('team', 5),
#   ('brighton', 5),
#   ('crew', 5),
#   ('trade', 5),
#   ('union', 5),
#   ('honour', 5),
#   ('claim', 5),
#   ('player', 5),
#   ('motorboat', 5),
#   ('interest', 5),
#   ('stroke', 5),
#   ('england', 4),
#   ('secretari', 4),
#   ('system', 4),
#   ('class', 4),
#   ('measur', 4),
#   ('author', 4),
#   ('child', 4),
#   ('offic', 4),
#   ('addit', 4),
#   ('premiership', 4),
#   ('everyth', 4),
#   ('sport', 4),
#   ('cash', 4),
#   ('light', 4),
#   ('march', 4),
#   ('period', 4),
#   ('capac', 4),
#   ('lorim', 4),
#   ('arrang', 4),
#   ('administr', 4),
#   ('flotat', 4),
#   ('india', 4),
#   ('cap', 4),
#   ('public', 4),
#   ('someth', 4),
#   ('politician', 4),
#   ('health', 4),
#   ('dubai', 4),
#   ('rain', 4),
#   ('break', 4),
#   ('control', 4),
#   ('start', 4),
#   ('championship', 4),
#   ('ferdinand', 4),
#   ('britain', 4),
#   ('area', 4),
#   ('live', 4),
#   ('deadlin', 4),
#   ('divis', 4),
#   ('unit', 4),
#   ('tuesday', 4),
#   ('option', 4),
#   ('europ', 4),
#   ('citi', 4),
#   ('weekend', 4),
#   ('visit', 4),
#   ('plymouth', 4),
#   ('liverpool', 4),
#   ('palac', 4),
#   ('afford', 4),
#   ('bolton', 4),
#   ('cardiff', 4),
#   ('preston', 4),
#   ('northampton', 4),
#   ('middlesbrough', 4),
#   ('read', 4),
#   ('wage', 4),
#   ('childcar', 4),
#   ('poverti', 4),
#   ('london', 4),
#   ('teenag', 4),
#   ('trophi', 4),
#   ('bit', 4),
#   ('rugbi', 4),
#   ('motorcycl', 4),
#   ('stanley', 4),
#   ('gear', 4),
#   ('news', 4),
#   ('return', 4),
#   ('profit', 4),
#   ('gill', 4),
#   ('food', 4),
#   ('panel', 4),
#   ('celeb', 4),
#   ('approv', 4),
#   ('ada', 4),
#   ('kim', 4),
#   ('inform', 4),
#   ('graham', 4),
#   ('safeti', 4),
#   ('diseas', 4),
#   ('immunis', 4),
#   ('mongrel', 4),
#   ('labour', 4),
#   ('today', 4),
#   ('penalti', 3),
#   ('notic', 3),
#   ('children', 3),
#   ('scheme', 3),
#   ('attend', 3),
#   ('truanci', 3),
#   ('hit', 3),
#   ('half', 3),
#   ('nation', 3),
#   ('lot', 3),
#   ('forward', 3),
#   ('road', 3),
#   ('chequ', 3),
#   ('discuss', 3),
#   ('wednesday', 3),
#   ('footbal', 3),
#   ('debat', 3),
#   ('donor', 3),
#   ('call', 3),
#   ('limit', 3),
#   ('futur', 3),
#   ('candid', 3),
#   ('campaign', 3),
#   ('taxpay', 3),
#   ('amount', 3),
#   ('differ', 3),
#   ('voter', 3),
#   ('spend', 3),
#   ('ivan', 3),
#   ('victori', 3),
#   ('weather', 3),
#   ('form', 3),
#   ('scott', 3),
#   ('indoor', 3),
#   ('circuit', 3),
#   ('scot', 3),
#   ('meet', 3),
#   ('brit', 3),
#   ('label', 3),
#   ('don', 3),
#   ('art', 3),
#   ('grant', 3),
#   ('valu', 3),
#   ('show', 3),
#   ('move', 3),
#   ('support', 3),
#   ('allianc', 3),
#   ('oper', 3),
#   ('arm', 3),
#   ('troubl', 3),
#   ('home', 3),
#   ('season', 3),
#   ('birmingham', 3),
#   ('action', 3),
#   ('strategi', 3),
#   ('hollywood', 3),
#   ('actor', 3),
#   ('kevin', 3),
#   ('bacon', 3),
#   ('paedophil', 3),
#   ('woodsman', 3),
#   ('strait', 3),
#   ('ray', 3),
#   ('kassel', 3),
#   ('jail', 3),
#   ('judg', 3),
#   ('subject', 3),
#   ('insight', 3),
#   ('sensit', 3),
#   ('boy', 3),
#   ('cri', 3),
#   ('stori', 3),
#   ('brandon', 3),
#   ('gamma', 3),
#   ('santa', 3),
#   ('featur', 3),
#   ('wale', 3),
#   ('mother', 3),
#   ('tens', 3),
#   ('neighbour', 3),
#   ('night', 3),
#   ('fire', 3),
#   ('handicap', 3),
#   ('sutherland', 3),
#   ('jonathan', 3),
#   ('cassett', 3),
#   ('tarnat', 3),
#   ('maccabe', 3),
#   ('jude', 3),
#   ('law', 3),
#   ('hoffman', 3),
#   ('king', 3),
#   ('par', 3),
#   ('anim', 3),
#   ('incred', 3),
#   ('bullet', 3),
#   ('rapper', 3),
#   ('asher', 3),
#   ('roger', 3),
#   ('chanc', 3),
#   ('seven', 3),
#   ('endeavour', 3),
#   ('technolog', 3),
#   ('display', 3),
#   ('bodi', 3),
#   ('clutch', 3),
#   ('pedal', 3),
#   ('earn', 3),
#   ('cost', 3),
#   ('speech', 3),
#   ('develop', 3),
#   ('main', 3),
#   ('opposit', 3),
#   ('anyth', 3),
#   ('contract', 2),
#   ('tori', 2),
#   ('issu', 2),
#   ('absenc', 2),
#   ('crime', 2),
#   ('forc', 2),
#   ('stanc', 2),
#   ('patrol', 2),
#   ('depart', 2),
#   ('seal', 2),
#   ('get', 2),
#   ('friday', 2),
#   ('mantel', 2),
#   ('guis', 2),
#   ('leland', 2),
#   ('stadium', 2),
#   ('thorp', 2),
#   ('arch', 2),
#   ('ground', 2),
#   ('jon', 2),
#   ('task', 2),
#   ('flow', 2),
#   ('sort', 2),
#   ('creditor', 2),
#   ('tunnel', 2),
#   ('matter', 2),
#   ('gerald', 2),
#   ('medium', 2),
#   ('surviv', 2),
#   ('date', 2),
#   ('percent', 2),
#   ('agreement', 2),
#   ('consortium', 2),
#   ('background', 2),
#   ('smooth', 2),
#   ('contact', 2),
#   ('mccormick', 2),
#   ('consult', 2),
#   ('loan', 2),
#   ('yvonn', 2),
#   ('todd', 2),
#   ('lawyer', 2),
#   ('mark', 2),
#   ('taylor', 2),
#   ('detail', 2),
#   ('person', 2),
#   ('roman', 2),
#   ('stamford', 2),
#   ('bridg', 2),
#   ('salisburi', 2),
#   ('brink', 2),
#   ('deduct', 2),
#   ('prospect', 2),
#   ('pc', 2),
#   ('mix', 2),
#   ('rupe', 2),
#   ('softwar', 2),
#   ('bet', 2),
#   ('economi', 2),
#   ('util', 2),
#   ('watchdog', 2),
#   ('gift', 2),
#   ('rule', 2),
#   ('principl', 2),
#   ('chang', 2),
#   ('relief', 2),
#   ('common', 2),
#   ('parliament', 2),
#   ('assembl', 2),
#   ('ireland', 2),
#   ('polit', 2),
#   ('tim', 2),
#   ('progress', 2),
#   ('win', 2),
#   ('fifth', 2),
#   ('tommi', 2),
#   ('roberto', 2),
#   ('liefer', 2),
#   ('germani', 2),
#   ('afterward', 2),
#   ('umpir', 2),
#   ('doe', 2),
#   ('score', 2),
#   ('irrelev', 2),
#   ('desert', 2),
#   ('advanc', 2),
#   ('kornberg', 2),
#   ('arriv', 2),
#   ('lectur', 2),
#   ('output', 2),
#   ('univers', 2),
#   ('event', 2),
#   ('seri', 2),
#   ('band', 2),
#   ('stereotyp', 2),
#   ('morn', 2),
#   ('hostil', 2),
#   ('toward', 2),
#   ('speaker', 2),
#   ('compos', 2),
#   ('appear', 2),
#   ('artist', 2),
#   ('licenc', 2),
#   ('pound', 2),
#   ('exampl', 2),
#   ('joy', 2),
#   ('sens', 2),
#   ('franz', 2),
#   ('facil', 2),
#   ('earth', 2),
#   ('line', 2),
#   ('hand', 2),
#   ('near', 2),
#   ('motor', 2),
#   ('disagr', 2),
#   ('talk', 2),
#   ('gain', 2),
#   ('hope', 2),
#   ('payoff', 2),
#   ('decis', 2),
#   ('halv', 2),
#   ('outright', 2),
#   ('giant', 2),
#   ('godfath', 2),
#   ('put', 2),
#   ('saab', 2),
#   ('manag', 2),
#   ('patrick', 2),
#   ('auto', 2),
#   ('bank', 2),
#   ('newcastl', 2),
#   ('trip', 2),
#   ('highlight', 2),
#   ('slough', 2),
#   ('round', 2),
#   ('doncast', 2),
#   ('saturday', 2),
#   ('strafford', 2),
#   ('holder', 2),
#   ('arsen', 2),
#   ('host', 2),
#   ('brantford', 2),
#   ('sunday', 2),
#   ('replay', 2),
#   ('martin', 2),
#   ('griffin', 2),
#   ('park', 2),
#   ('travel', 2),
#   ('villa', 2),
#   ('sheffield', 2),
#   ('struggl', 2),
#   ('carl', 2),
#   ('counti', 2),
#   ('spur', 2),
#   ('hart', 2),
#   ('lane', 2),
#   ('exet', 2),
#   ('leicest', 2),
#   ('blackpool', 2),
#   ('sunderland', 2),
#   ('wolv', 2),
#   ('hull', 2),
#   ('colchest', 2),
#   ('nottingham', 2),
#   ('boston', 2),
#   ('milton', 2),
#   ('keyn', 2),
#   ('oldham', 2),
#   ('charlton', 2),
#   ('rochdal', 2),
#   ('shelf', 2),
#   ('aston', 2),
#   ('west', 2),
#   ('evil', 2),
#   ('burnley', 2),
#   ('bournemouth', 2),
#   ('chester', 2),
#   ('coventri', 2),
#   ('durham', 2),
#   ('portsmouth', 2),
#   ('southampton', 2),
#   ('apr', 2),
#   ('luton', 2),
#   ('congress', 2),
#   ('budget', 2),
#   ('care', 2),
#   ('provis', 2),
#   ('brendan', 2),
#   ('barber', 2),
#   ('frontlin', 2),
#   ('women', 2),
#   ('decent', 2),
#   ('list', 2),
#   ('cubic', 2),
#   ('star', 2),
#   ('confid', 2),
#   ('ball', 2),
#   ('burger', 2),
#   ('champion', 2),
#   ('gordon', 2),
#   ('franc', 2),
#   ('amor', 2),
#   ('vehicl', 2),
#   ('racer', 2),
#   ('leg', 2),
#   ('ampute', 2),
#   ('gearbox', 2),
#   ('rider', 2),
#   ('throttl', 2),
#   ('brake', 2),
#   ('wheel', 2),
#   ('rise', 2),
#   ('peak', 2),
#   ('trough', 2),
#   ('volatil', 2),
#   ('reserv', 2),
#   ('investor', 2),
#   ('price', 2),
#   ('aka', 2),
#   ('sun', 2),
#   ('recoveri', 2),
#   ('payout', 2),
#   ('type', 2),
#   ('pain', 2),
#   ('verdict', 2),
#   ('evid', 2),
#   ('brand', 2),
#   ('name', 2),
#   ('shop', 2),
#   ('shelv', 2),
#   ('battl', 2),
#   ('septemb', 2),
#   ('million', 2),
#   ('dollar', 2),
#   ('litig', 2),
#   ('alarm', 2),
#   ('bell', 2),
#   ('note', 2),
#   ('pfizer', 2),
#   ('user', 2),
#   ('stomach', 2),
#   ('investig', 2),
#   ('announc', 2),
#   ('reintroduct', 2),
#   ('caught', 2),
#   ('surpris', 2),
#   ('head', 2),
#   ('therapi', 2),
#   ('uniqu', 2),
#   ('calcul', 2),
#   ('death', 2),
#   ('stem', 2),
#   ('handl', 2),
#   ('medicin', 2),
#   ('agenc', 2),
#   ('doctor', 2),
#   ('factor', 2),
#   ('pledg', 2),
#   ('chancellor', 2),
#   ('brown', 2),
#   ('vaccin', 2),
#   ('bill', 2),
#   ('foundat', 2),
#   ('gave', 2),
#   ('blair', 2),
#   ('tactic', 2),
#   ('tell', 2),
#   ('someon', 2),
#   ('radio', 2),
#   ('immigr', 2),
#   ('shield', 2),
#   ('wilburn', 2),
#   ('target', 1),
#   ('crackdown', 1),
#   ('ruth', 1),
#   ('initi', 1),
#   ('statist', 1),
#   ('track', 1),
#   ('prosecut', 1),
#   ('holiday', 1),
#   ('classroom', 1),
#   ('remaind', 1),
#   ('improv', 1),
#   ('equival', 1),
#   ('sixth', 1),
#   ('polic', 1),
#   ('welfar', 1),
#   ('hotshot', 1),
#   ('sweep', 1),
#   ('youngster', 1),
#   ('skill', 1),
#   ('sourc', 1),
#   ('count', 1),
#   ('tool', 1),
#   ('fear', 1),
#   ('favour', 1),
#   ('suspicion', 1),
#   ('introduct', 1),
#   ('departur', 1),
#   ('incom', 1),
#   ('member', 1),
#   ('hous', 1),
#   ('welsh', 1),
#   ('mailshot', 1),
#   ('leaflet', 1),
#   ('shift', 1),
#   ('poll', 1),
#   ('happen', 1),
#   ('younger', 1),
#   ('doubt', 1),
#   ('democraci', 1),
#   ('consensu', 1),
#   ('allan', 1),
#   ('medal', 1),
#   ('hurdl', 1),
#   ('madrid', 1),
#   ('learn', 1),
#   ('curv', 1),
#   ('bride', 1),
#   ('sweden', 1),
#   ('robert', 1),
#   ('dudley', 1),
#   ('run', 1),
#   ('heat', 1),
#   ('pix', 1),
#   ('ran', 1),
#   ('clock', 1),
#   ('frontal', 1),
#   ('kind', 1),
#   ('input', 1),
#   ('map', 1),
#   ('scotland', 1),
#   ('centuri', 1),
#   ('element', 1),
#   ('susten', 1),
#   ('tea', 1),
#   ('idea', 1),
#   ('glasgow', 1),
#   ('mercuri', 1),
#   ('singl', 1),
#   ('audienc', 1),
#   ('reid', 1),
#   ('hall', 1),
#   ('rang', 1),
#   ('individu', 1),
#   ('angst', 1),
#   ('mingl', 1),
#   ('scissor', 1),
#   ('sister', 1),
#   ('upbeat', 1),
#   ('smell', 1),
#   ('napalm', 1),
#   ('creativ', 1),
#   ('fellow', 1),
#   ('jame', 1),
#   ('abil', 1),
#   ('edinburgh', 1),
#   ('mikhail', 1),
#   ('gorbachev', 1),
#   ('professor', 1),
#   ('stephen', 1),
#   ('daunt', 1),
#   ('brain', 1),
#   ('tonight', 1),
#   ('entertain', 1),
#   ('venu', 1),
#   ('louder', 1),
#   ('voic', 1),
#   ('megastar', 1),
#   ('album', 1),
#   ('concert', 1),
#   ('demand', 1),
#   ('lotteri', 1),
#   ('opera', 1),
#   ('divers', 1),
#   ('opportun', 1),
#   ('cultur', 1),
#   ('travi', 1),
#   ('good', 1),
#   ('answer', 1),
#   ('passion', 1),
#   ('pay', 1),
#   ('subsidi', 1),
#   ('dream', 1),
#   ('jump', 1),
#   ('posit', 1),
#   ('sponsorship', 1),
#   ('mass', 1),
#   ('thousand', 1),
#   ('thumb', 1),
#   ('use', 1),
#   ('treasuri', 1),
#   ('chariti', 1),
#   ('equip', 1),
#   ('mean', 1),
#   ('extent', 1),
#   ('condit', 1),
#   ('respons', 1),
#   ('mould', 1),
#   ('busi', 1),
#   ('breakthrough', 1),
#   ('act', 1),
#   ('yeah', 1),
#   ('veteran', 1),
#   ('attent', 1),
#   ('fratern', 1),
#   ('merit', 1),
#   ('origin', 1),
#   ('whatsoev', 1),
#   ('pocket', 1),
#   ('pollut', 1),
#   ('avenu', 1),
#   ('solut', 1),
#   ('organ', 1),
#   ('test', 1),
#   ('tiebreak', 1),
#   ('cool', 1),
#   ('style', 1),
#   ('decid', 1),
#   ('tournament', 1),
#   ('rotterdam', 1),
#   ('rhythm', 1),
#   ('serv', 1),
#   ('racket', 1),
#   ('court', 1),
#   ('defeat', 1),
#   ('boost', 1),
#   ('south', 1),
#   ('flanker', 1),
#   ('armi', 1),
#   ('sensat', 1),
#   ('matt', 1),
#   ('gateau', 1),
#   ('jake', 1),
#   ('slam', 1),
#   ('winner', 1),
#   ('beat', 1),
#   ('roll', 1),
#   ('lucio', 1),
#   ('lopez', 1),
#   ('tribut', 1),
#   ('emerg', 1),
#   ('monti', 1),
#   ('rhode', 1),
#   ('cricket', 1),
#   ('career', 1),
#   ('ira', 1),
#   ('moment', 1),
#   ('gloucest', 1),
#   ('tech', 1),
#   ('speed', 1),
#   ('demon', 1),
#   ('organis', 1),
#   ('aspect', 1),
#   ('thank', 1),
#   ('innov', 1),
#   ('grid', 1),
#   ('yesterday', 1),
#   ('gosport', 1),
#   ('new', 1),
#   ('roy', 1),
#   ('derbi', 1),
#   ('changer', 1),
#   ('accid', 1),
#   ('websit', 1),
#   ('foot', 1),
#   ('heath', 1),
#   ('robinson', 1),
#   ('devic', 1),
#   ('sidecar', 1),
#   ('invent', 1),
#   ('zealand', 1),
#   ('reckon', 1),
#   ('save', 1),
#   ('second', 1),
#   ('lap', 1),
#   ('isl', 1),
#   ('result', 1),
#   ('exhibit', 1),
#   ('stand', 1),
#   ('impresa', 1),
#   ('ralli', 1),
#   ('varieti', 1),
#   ('disabl', 1),
#   ('driver', 1),
#   ('lincolnshir', 1),
#   ('hawkin', 1),
#   ('parapleg', 1),
#   ('custom', 1),
#   ('quadripleg', 1),
#   ('woman', 1),
#   ('limb', 1),
#   ('marshal', 1),
#   ('psi', 1),
#   ('subaru', 1),
#   ('duck', 1),
#   ('switch', 1),
#   ('stick', 1),
#   ('ring', 1),
#   ('bar', 1),
#   ('raini', 1),
#   ('tradit', 1),
#   ('father', 1),
#   ('murray', 1),
#   ('formula', 1),
#   ('daughter', 1),
#   ('statur', 1),
#   ('hill', 1),
#   ('climb', 1),
#   ('extens', 1),
#   ('cushion', 1),
#   ('back', 1),
#   ('seat', 1),
#   ('complet', 1),
#   ('balanc', 1),
#   ('column', 1),
#   ('lever', 1),
#   ('marathon', 1),
#   ('drive', 1),
#   ('partner', 1),
#   ('trevor', 1),
#   ('engin', 1),
#   ('morri', 1),
#   ('adapt', 1),
#   ('minut', 1),
#   ('millennium', 1),
#   ('declar', 1),
#   ('goal', 1),
#   ('mortal', 1),
#   ('tour', 1),
#   ('aid', 1),
#   ('gate', 1),
#   ('collater', 1),
#   ('capit', 1),
#   ('thereaft', 1),
#   ('friend', 1),
#   ('movement', 1),
#   ('barrier', 1),
#   ('john', 1),
#   ('hilari', 1),
#   ('rhetor', 1),
#   ('realiti', 1),
#   ('continu', 1),
#   ('privatis', 1),
#   ('jibe', 1),
#   ('michael', 1),
#   ('spring', 1),
#   ('legisl', 1),
#   ('play', 1),
#   ('sake', 1),
#   ('pig', 1),
#   ('environ', 1),
#   ('margaret', 1),
#   ('beckett', 1),
#   ('comment', 1),
#   ('duti', 1),
#   ('judgement', 1),
#   ('behalf', 1),
#   ('chord', 1),
#   ('begin', 1),
#   ('dixon', 1),
#   ('headlin', 1),
#   ('quota', 1),
#   ('focu', 1),
#   ('media', 1),
#   ('coverag', 1),
#   ('cleaner', 1),
#   ('hospit', 1),
#   ('disciplin', 1),
#   ('promis', 1),
#   ('correct', 1),
#   ('curriculum', 1),
#   ('tape', 1),
#   ('appeal', 1),
#   ('activist', 1),
#   ('grandchildren', 1),
#   ('alan', 1),
#   ('vision', 1),
#   ('refer', 1),
#   ('stage', 1)],
#  [('technolog', 51),
#   ('network', 30),
#   ('panda', 28),
#   ('sound', 27),
#   ('audio', 21),
#   ('phone', 21),
#   ('world', 20),
#   ('research', 18),
#   ('game', 18),
#   ('reserv', 16),
#   ('wireless', 12),
#   ('staff', 12),
#   ('compani', 12),
#   ('handset', 12),
#   ('ear', 12),
#   ('director', 10),
#   ('firm', 9),
#   ('monteith', 9),
#   ('bit', 9),
#   ('market', 9),
#   ('popul', 8),
#   ('natur', 8),
#   ('data', 8),
#   ('long', 8),
#   ('children', 8),
#   ('inform', 7),
#   ('surround', 7),
#   ('system', 7),
#   ('field', 7),
#   ('media', 6),
#   ('devic', 6),
#   ('head', 6),
#   ('month', 6),
#   ('chip', 6),
#   ('brain', 6),
#   ('process', 6),
#   ('right', 6),
#   ('differ', 6),
#   ('impact', 6),
#   ('music', 6),
#   ('japan', 6),
#   ('hand', 4),
#   ('internet', 4),
#   ('provinc', 4),
#   ('china', 4),
#   ('broadband', 4),
#   ('activ', 4),
#   ('imag', 4),
#   ('colleagu', 4),
#   ('breed', 4),
#   ('bamboo', 4),
#   ('ecolog', 4),
#   ('vet', 4),
#   ('feed', 4),
#   ('suggest', 4),
#   ('chang', 4),
#   ('cub', 4),
#   ('chanc', 4),
#   ('way', 4),
#   ('share', 4),
#   ('rest', 4),
#   ('hang', 4),
#   ('intel', 4),
#   ('video', 4),
#   ('monitor', 4),
#   ('camera', 4),
#   ('clock', 4),
#   ('infrastructur', 4),
#   ('park', 4),
#   ('disk', 4),
#   ('health', 4),
#   ('paper', 4),
#   ('notebook', 4),
#   ('team', 4),
#   ('access', 4),
#   ('link', 4),
#   ('globe', 4),
#   ('lab', 4),
#   ('collabor', 4),
#   ('globin', 4),
#   ('organis', 4),
#   ('primari', 4),
#   ('school', 4),
#   ('peer', 4),
#   ('portland', 4),
#   ('oregon', 4),
#   ('stori', 4),
#   ('life', 4),
#   ('dialogu', 4),
#   ('bridg', 4),
#   ('cultur', 4),
#   ('founder', 4),
#   ('gerri', 4),
#   ('elli', 4),
#   ('enter', 3),
#   ('dimens', 3),
#   ('player', 3),
#   ('buzz', 3),
#   ('bee', 3),
#   ('jump', 3),
#   ('back', 3),
#   ('demo', 3),
#   ('heard', 3),
#   ('home', 3),
#   ('cinema', 3),
#   ('synapt', 3),
#   ('number', 3),
#   ('speaker', 3),
#   ('offer', 3),
#   ('david', 3),
#   ('mobil', 3),
#   ('nicer', 3),
#   ('channel', 3),
#   ('doom', 3),
#   ('standard', 3),
#   ('fujitsu', 3),
#   ('mitsubishi', 3),
#   ('marker', 3),
#   ('yamaha', 3),
#   ('room', 3),
#   ('pc', 3),
#   ('consol', 3),
#   ('time', 3),
#   ('consum', 3),
#   ('scienc', 3),
#   ('sinbad', 3),
#   ('area', 3),
#   ('structur', 3),
#   ('encod', 3),
#   ('understand', 3),
#   ('mic', 3),
#   ('impress', 3),
#   ('left', 3),
#   ('listen', 3),
#   ('fact', 3),
#   ('sourc', 3),
#   ('side', 3),
#   ('shape', 3),
#   ('caus', 3),
#   ('download', 3),
#   ('handheld', 3),
#   ('limit', 3),
#   ('screen', 3),
#   ('definit', 3),
#   ('movi', 3),
#   ('fish', 3),
#   ('titl', 3),
#   ('gamer', 3),
#   ('shoot', 3),
#   ('pm', 3),
#   ('develop', 3),
#   ('song', 3),
#   ('feel', 3),
#   ('softwar', 3),
#   ('version', 3),
#   ('effici', 3),
#   ('processor', 3),
#   ('danon', 3),
#   ('place', 3),
#   ('us', 3)],
#  [('peopl', 18),
#   ('law', 17),
#   ('terror', 16),
#   ('power', 14),
#   ('right', 13),
#   ('blog', 12),
#   ('clark', 11),
#   ('hous', 10),
#   ('evid', 10),
#   ('viru', 10),
#   ('fri', 10),
#   ('use', 9),
#   ('court', 9),
#   ('arrest', 8),
#   ('citizen', 8),
#   ('home', 8),
#   ('secretari', 8),
#   ('lord', 8),
#   ('internet', 8),
#   ('case', 8),
#   ('servic', 8),
#   ('recipi', 8),
#   ('attach', 8),
#   ('chang', 7),
#   ('cell', 7),
#   ('firm', 7),
#   ('yukon', 7),
#   ('month', 7),
#   ('measur', 6),
#   ('control', 6),
#   ('suspect', 6),
#   ('govern', 6),
#   ('terrorist', 6),
#   ('secur', 6),
#   ('research', 6),
#   ('oil', 6),
#   ('journal', 6),
#   ('comput', 6),
#   ('part', 5),
#   ('prison', 5),
#   ('threat', 5),
#   ('judg', 5),
#   ('stem', 5),
#   ('compani', 5),
#   ('year', 5),
#   ('detent', 4),
#   ('trial', 4),
#   ('order', 4),
#   ('anyon', 4),
#   ('abus', 4),
#   ('detaine', 4),
#   ('attack', 4),
#   ('nation', 4),
#   ('map', 4),
#   ('call', 4),
#   ('rule', 4),
#   ('group', 4),
#   ('tax', 4),
#   ('bankruptci', 4),
#   ('space', 4),
#   ('competitor', 4),
#   ('googl', 4),
#   ('account', 4),
#   ('number', 4),
#   ('exist', 4),
#   ('bureau', 4),
#   ('gov', 4),
#   ('messag', 4),
#   ('agenc', 4),
#   ('public', 4),
#   ('us', 3),
#   ('societi', 3),
#   ('effort', 3),
#   ('role', 3),
#   ('plan', 3),
#   ('life', 3),
#   ('howard', 3),
#   ('hope', 3),
#   ('million', 3),
#   ('tissu', 3),
#   ('live', 3),
#   ('way', 3),
#   ('state', 3),
#   ('auction', 3),
#   ('giant', 3),
#   ('houston', 3),
#   ('fraud', 3),
#   ('face', 2),
#   ('involv', 2),
#   ('seri', 2),
#   ('charl', 2),
#   ('curfew', 2),
#   ('propos', 2),
#   ('deal', 2),
#   ('london', 2),
#   ('septemb', 2),
#   ('countri', 2),
#   ('origin', 2),
#   ('algeria', 2),
#   ('egypt', 2),
#   ('jordan', 2),
#   ('tortur', 2),
#   ('death', 2),
#   ('restrict', 2),
#   ('movement', 2),
#   ('limit', 2),
#   ('telephon', 2),
#   ('intellig', 2),
#   ('report', 2),
#   ('lawyer', 2),
#   ('clive', 2),
#   ('britain', 2),
#   ('prosecut', 2),
#   ('prefer', 2),
#   ('scrutini', 2),
#   ('emerg', 2),
#   ('prevent', 2),
#   ('deter', 2),
#   ('place', 2),
#   ('sourc', 2),
#   ('risk', 2),
#   ('shadow', 2),
#   ('david', 2),
#   ('davi', 2),
#   ('histori', 2),
#   ('intern', 2),
#   ('resent', 2),
#   ('process', 2),
#   ('democrat', 2),
#   ('spokesman', 2),
#   ('mark', 2),
#   ('oaten', 2),
#   ('standard', 2),
#   ('proof', 2),
#   ('minist', 2),
#   ('liberti', 2),
#   ('adher', 2),
#   ('game', 2),
#   ('cat', 2),
#   ('futur', 2),
#   ('issu', 2),
#   ('scienc', 2),
#   ('alzheim', 2),
#   ('parkinson', 2),
#   ('motor', 2),
#   ('neuron', 2),
#   ('diseas', 2),
#   ('duti', 2),
#   ('ill', 2),
#   ('heart', 2),
#   ('concern', 2),
#   ('ambit', 2),
#   ('product', 2),
#   ('unit', 2),
#   ('damag', 2),
#   ('suit', 2),
#   ('invest', 2),
#   ('bill', 2),
#   ('russia', 2),
#   ('busi', 2),
#   ('approx', 2),
#   ('robert', 2),
#   ('bug', 2),
#   ('softwar', 2),
#   ('microsoft', 2),
#   ('plung', 2),
#   ('world', 2),
#   ('test', 2),
#   ('log', 2),
#   ('opinion', 2),
#   ('hobnail', 2),
#   ('messeng', 2),
#   ('layout', 2),
#   ('page', 2),
#   ('imag', 2),
#   ('share', 2),
#   ('photo', 2),
#   ('album', 2),
#   ('music', 2),
#   ('banner', 2),
#   ('tool', 2),
#   ('web', 2),
#   ('phenomenon', 2),
#   ('blogger', 2),
#   ('site', 2),
#   ('member', 2),
#   ('figur', 2),
#   ('analysi', 2),
#   ('biospher', 2),
#   ('quarter', 2),
#   ('warn', 2),
#   ('investig', 2),
#   ('purport', 2),
#   ('show', 2),
#   ('address', 2),
#   ('tell', 2),
#   ('complaint', 2),
#   ('enter', 2),
#   ('contain', 2),
#   ('question', 2),
#   ('questionnair', 2),
#   ('user', 2),
#   ('solicit', 2),
#   ('practic', 2),
#   ('manner', 2),
#   ('statement', 2),
#   ('phoney', 2),
#   ('breach', 2),
#   ('spokeswoman', 2),
#   ('incid', 2),
#   ('back', 1),
#   ('michael', 1),
#   ('featur', 1),
#   ('elect', 1),
#   ('georg', 1),
#   ('bush', 1),
#   ('leader', 1),
#   ('victim', 1),
#   ('abil', 1),
#   ('bodi', 1),
#   ('type', 1),
#   ('scientist', 1),
#   ('laboratori', 1),
#   ('brain', 1),
#   ('nostalg', 1),
#   ('past', 1),
#   ('politician', 1),
#   ('framework', 1),
#   ('potenti', 1),
#   ('benefit', 1),
#   ('mankind', 1),
#   ('expect', 1),
#   ('briton', 1),
#   ('respons', 1),
#   ('qualiti', 1),
#   ('stuff', 1),
#   ('soul', 1),
#   ('sclerosi', 1),
#   ('paper', 1),
#   ('today', 1),
#   ('problem', 1),
#   ('answer', 1),
#   ('courag', 1),
#   ('cours', 1),
#   ('discoveri', 1),
#   ('superman', 1),
#   ('christoph', 1),
#   ('reev', 1),
#   ('advoc', 1),
#   ('hors', 1),
#   ('remark', 1),
#   ('speech', 1),
#   ('westminst', 1),
#   ('women', 1),
#   ('committe', 1),
#   ('valu', 1),
#   ('lugansk', 1),
#   ('decemb', 1),
#   ('ga', 1),
#   ('baikal', 1),
#   ('disput', 1),
#   ('arbitr', 1),
#   ('reorganis', 1),
#   ('chapter', 1),
#   ('clash', 1),
#   ('kremlin', 1),
#   ('head', 1),
#   ('fine', 1),
#   ('sale', 1),
#   ('illeg', 1),
#   ('mean', 1),
#   ('dispos', 1),
#   ('asset', 1),
#   ('analyst', 1),
#   ('jurisdict', 1),
#   ('moscow', 1),
#   ('offici', 1),
#   ('wrangl', 1),
#   ('meaningless', 1),
#   ('leta', 1),
#   ('hear', 1),
#   ('argument', 1),
#   ('forum', 1),
#   ('action', 1),
#   ('file', 1),
#   ('effect', 1),
#   ('battl', 1),
#   ('withdrew', 1),
#   ('financ', 1),
#   ('day', 1),
#   ('meanwhil', 1),
#   ('chunk', 1),
#   ('claim', 1),
#   ('sharehold', 1),
#   ('founder', 1),
#   ('mikhail', 1),
#   ('richest', 1),
#   ('evas', 1),
#   ('bail', 1)],
#  [('game', 29),
#   ('ireland', 27),
#   ('england', 20),
#   ('tri', 20),
#   ('ball', 19),
#   ('compani', 16),
#   ('jersey', 15),
#   ('coach', 12),
#   ('way', 12),
#   ('refere', 11),
#   ('kick', 11),
#   ('line', 11),
#   ('decis', 10),
#   ('plan', 10),
#   ('auto', 10),
#   ('benin', 10),
#   ('corner', 9),
#   ('dodgson', 8),
#   ('defenc', 8),
#   ('argonaut', 8),
#   ('player', 7),
#   ('turnov', 7),
#   ('time', 7),
#   ('rugbi', 6),
#   ('camera', 6),
#   ('piec', 6),
#   ('matt', 6),
#   ('charli', 6),
#   ('robinson', 6),
#   ('minut', 6),
#   ('moment', 6),
#   ('cornel', 6),
#   ('derek', 6),
#   ('titan', 6),
#   ('offici', 6),
#   ('match', 5),
#   ('nation', 5),
#   ('side', 5),
#   ('doubt', 5),
#   ('sport', 5),
#   ('jonathan', 5),
#   ('mark', 5),
#   ('sale', 5),
#   ('cash', 5),
#   ('london', 5),
#   ('loss', 5),
#   ('win', 4),
#   ('administr', 4),
#   ('news', 4),
#   ('briberi', 4),
#   ('telecommun', 4),
#   ('campaign', 4),
#   ('presid', 4),
#   ('practic', 4),
#   ('error', 3),
#   ('board', 3),
#   ('thing', 3),
#   ('field', 3),
#   ('perpetr', 3),
#   ('knuckl', 3),
#   ('ira', 3),
#   ('footbal', 3),
#   ('scenario', 3),
#   ('slang', 3),
#   ('landown', 3),
#   ('road', 3),
#   ('exampl', 3),
#   ('step', 3),
#   ('slam', 3),
#   ('frustrat', 3),
#   ('rub', 3),
#   ('green', 3),
#   ('victori', 3),
#   ('reaction', 3),
#   ('camp', 3),
#   ('blazer', 3),
#   ('mean', 3),
#   ('villain', 3),
#   ('comment', 3),
#   ('recours', 3),
#   ('critic', 3),
#   ('simon', 3),
#   ('judg', 3),
#   ('scotland', 3),
#   ('william', 3),
#   ('defeat', 3),
#   ('franc', 3),
#   ('queri', 3),
#   ('case', 3),
#   ('raven', 3),
#   ('ulster', 3),
#   ('gloucest', 3),
#   ('cup', 3),
#   ('occas', 3),
#   ('humphrey', 3),
#   ('bowl', 3),
#   ('angl', 3),
#   ('anomali', 3),
#   ('josh', 3),
#   ('claim', 3),
#   ('control', 3),
#   ('credit', 3),
#   ('flanker', 3),
#   ('johnni', 3),
#   ('evid', 3),
#   ('everyth', 3),
#   ('greenock', 3),
#   ('martin', 3),
#   ('sorri', 3),
#   ('stroll', 3),
#   ('foe', 3),
#   ('bristol', 3),
#   ('display', 3),
#   ('highlight', 3),
#   ('roman', 3),
#   ('gari', 3),
#   ('abil', 3),
#   ('compon', 3),
#   ('defin', 3),
#   ('cosh', 3),
#   ('play', 3),
#   ('vicki', 3),
#   ('brilliant', 3),
#   ('tackl', 3),
#   ('feet', 3),
#   ('colossu', 3),
#   ('paul', 3),
#   ('cordon', 3),
#   ('prop', 3),
#   ('ran', 3),
#   ('steam', 3),
#   ('tackler', 3),
#   ('volum', 3),
#   ('mike', 3),
#   ('ford', 3),
#   ('bow', 3),
#   ('championship', 3),
#   ('onlin', 3),
#   ('year', 3),
#   ('develop', 3),
#   ('redund', 3),
#   ('staff', 3),
#   ('dent', 3),
#   ('johnson', 3),
#   ('focu', 3),
#   ('maker', 2),
#   ('harri', 2),
#   ('potter', 2),
#   ('employe', 2),
#   ('share', 2),
#   ('trade', 2),
#   ('stock', 2),
#   ('exchang', 2),
#   ('headquart', 2),
#   ('cambridg', 2),
#   ('flow', 2),
#   ('deal', 2),
#   ('troubl', 2),
#   ('parkinson', 2),
#   ('peopl', 2),
#   ('job', 2),
#   ('busi', 2),
#   ('puzzl', 2),
#   ('wasp', 2),
#   ('wing', 2),
#   ('bic', 2),
#   ('ground', 2),
#   ('let', 2),
#   ('whistl', 2),
#   ('surpris', 2),
#   ('incid', 2),
#   ('effort', 2),
#   ('element', 2),
#   ('move', 2),
#   ('techniqu', 2),
#   ('cuff', 2),
#   ('today', 2),
#   ('level', 2),
#   ('jaclyn', 2),
#   ('state', 2),
#   ('corpor', 2),
#   ('mathew', 2),
#   ('price', 2),
#   ('project', 2),
#   ('suggest', 2),
#   ('wrongdo', 2),
#   ('account', 2),
#   ('law', 2),
#   ('penalti', 2),
#   ('lawsuit', 2),
#   ('secur', 2),
#   ('sec', 2),
#   ('agent', 2),
#   ('tie', 2),
#   ('money', 2),
#   ('slogan', 2),
#   ('elect', 2),
#   ('poll', 2),
#   ('manag', 2),
#   ('fee', 2),
#   ('attorney', 2),
#   ('carol', 2),
#   ('lam', 2),
#   ('note', 2),
#   ('conduct', 2),
#   ('toler', 2),
#   ('act', 2),
#   ('crime', 2),
#   ('firm', 2),
#   ('fight', 1),
#   ('britain', 1),
#   ('day', 1),
#   ('studio', 1),
#   ('softwar', 1),
#   ('publish', 1),
#   ('sign', 1),
#   ('august', 1),
#   ('delay', 1),
#   ('contract', 1),
#   ('part', 1),
#   ('measur', 1),
#   ('jason', 1),
#   ('lot', 1),
#   ('start', 1),
#   ('round', 1),
#   ('cut', 1),
#   ('edward', 1),
#   ('morphem', 1),
#   ('offic', 1),
#   ('town', 1),
#   ('monster', 1),
#   ('partner', 1),
#   ('friday', 1),
#   ('collaps', 1),
#   ('weekend', 1),
#   ('financ', 1),
#   ('cost', 1),
#   ('overhead', 1),
#   ('premis', 1),
#   ('us', 1),
#   ('express', 1),
#   ('interest', 1),
#   ('quarter', 1),
#   ('wage', 1),
#   ('pay', 1),
#   ('christma', 1),
#   ('taylor', 1),
#   ('hardcor', 1),
#   ('event', 1),
#   ('adelaid', 1),
#   ('ignacio', 1),
#   ('chela', 1),
#   ('joachim', 1),
#   ('sunday', 1),
#   ('seed', 1),
#   ('tens', 1),
#   ('belgium', 1),
#   ('boyfriend', 1),
#   ('clayton', 1),
#   ('hewitt', 1),
#   ('sister', 1),
#   ('support', 1),
#   ('saturday', 1),
#   ('home', 1),
#   ('live', 1),
#   ('set', 1),
#   ('tiebreak', 1),
#   ('concentr', 1),
#   ('call', 1),
#   ('mistak', 1)],
#  [('price', 18),
#   ('growth', 17),
#   ('quarter', 16),
#   ('year', 14),
#   ('economi', 12),
#   ('number', 10),
#   ('sequel', 10),
#   ('singapor', 9),
#   ('hous', 9),
#   ('effect', 8),
#   ('market', 8),
#   ('demand', 7),
#   ('rate', 7),
#   ('oil', 7),
#   ('blue', 7),
#   ('perform', 6),
#   ('figur', 6),
#   ('china', 6),
#   ('sector', 6),
#   ('electron', 6),
#   ('economist', 6),
#   ('tobacco', 6),
#   ('week', 6),
#   ('month', 6),
#   ('offic', 6),
#   ('bank', 6),
#   ('trade', 5),
#   ('analyst', 5),
#   ('virgin', 5),
#   ('share', 5),
#   ('profit', 5),
#   ('time', 5),
#   ('asia', 4),
#   ('slowdown', 4),
#   ('export', 4),
#   ('state', 4),
#   ('product', 4),
#   ('summer', 4),
#   ('fall', 4),
#   ('court', 4),
#   ('govern', 4),
#   ('level', 4),
#   ('england', 4),
#   ('twelv', 4),
#   ('box', 4),
#   ('ocean', 4),
#   ('clone', 4),
#   ('pitt', 4),
#   ('robert', 4),
#   ('weekend', 4),
#   ('decemb', 4),
#   ('film', 4),
#   ('lederberg', 4),
#   ('project', 4),
#   ('milder', 4),
#   ('mortgag', 4),
#   ('januari', 4),
#   ('ministri', 3),
#   ('advanc', 3),
#   ('manufactur', 3),
#   ('point', 3),
#   ('technolog', 3),
#   ('disast', 3),
#   ('servic', 3),
#   ('citi', 3),
#   ('forecast', 3),
#   ('drag', 3),
#   ('lang', 3),
#   ('chase', 3),
#   ('juli', 3),
#   ('period', 3),
#   ('car', 3),
#   ('viru', 3),
#   ('airlin', 3),
#   ('case', 3),
#   ('compani', 3),
#   ('smoke', 3),
#   ('firm', 3),
#   ('villa', 3),
#   ('return', 3),
#   ('holiday', 3),
#   ('york', 3),
#   ('increas', 3),
#   ('rise', 3),
#   ('declin', 3),
#   ('weather', 3),
#   ('barrel', 3),
#   ('budget', 2),
#   ('jester', 2),
#   ('august', 2),
#   ('novemb', 2),
#   ('atria', 2),
#   ('group', 2),
#   ('reynold', 2),
#   ('rule', 2),
#   ('injuri', 2),
#   ('carlton', 2),
#   ('cole', 2),
#   ('striker', 2),
#   ('loan', 2),
#   ('oper', 2),
#   ('ankl', 2),
#   ('problem', 2),
#   ('raid', 2),
#   ('crime', 2),
#   ('caper', 2),
#   ('georg', 2),
#   ('brad', 2),
#   ('julia', 2),
#   ('chart', 2),
#   ('ticket', 2),
#   ('sale', 2),
#   ('studio', 2),
#   ('master', 2),
#   ('crimin', 2),
#   ('heist', 2),
#   ('europ', 2),
#   ('treasur', 2),
#   ('place', 2),
#   ('wesley', 2),
#   ('snipe', 2),
#   ('triniti', 2),
#   ('express', 2),
#   ('hank', 2),
#   ('comedi', 2),
#   ('christma', 2),
#   ('rank', 2),
#   ('triumph', 2),
#   ('open', 2),
#   ('releas', 2),
#   ('lord', 2),
#   ('ring', 2),
#   ('predecessor', 2),
#   ('eleven', 2),
#   ('remak', 2),
#   ('sinatra', 2),
#   ('rat', 2),
#   ('pack', 2),
#   ('director', 2),
#   ('hit', 2),
#   ('damon', 2),
#   ('andi', 2),
#   ('garcia', 2),
#   ('elliott', 2),
#   ('gould', 2),
#   ('cast', 2),
#   ('fun', 2),
#   ('movi', 2),
#   ('presid', 2),
#   ('distribut', 2),
#   ('warner', 2),
#   ('critic', 2),
#   ('vaniti', 2),
#   ('review', 2),
#   ('us', 2),
#   ('build', 2),
#   ('societi', 2),
#   ('interest', 2),
#   ('approv', 2),
#   ('bannist', 2),
#   ('properti', 2),
#   ('lend', 2),
#   ('winter', 2),
#   ('temperatur', 2),
#   ('crude', 2),
#   ('fear', 2),
#   ('tax', 1),
#   ('execut', 1),
#   ('brett', 1),
#   ('richard', 1),
#   ('brandon', 1),
#   ('pressur', 1),
#   ('passeng', 1),
#   ('complet', 1),
#   ('half', 1),
#   ('fuel', 1),
#   ('cost', 1),
#   ('third', 1),
#   ('carrier', 1),
#   ('qanta', 1),
#   ('sky', 1),
#   ('sharehold', 1),
#   ('patrick', 1),
#   ('corpor', 1),
#   ('close', 1),
#   ('claim', 1),
#   ('countri', 1),
#   ('clinton', 1),
#   ('administr', 1),
#   ('decis', 1),
#   ('washington', 1),
#   ('law', 1),
#   ('biggest', 1),
#   ('brown', 1),
#   ('williamson', 1),
#   ('addict', 1),
#   ('teenag', 1),
#   ('dollar', 1),
#   ('advertis', 1),
#   ('campaign', 1),
#   ('danger', 1),
#   ('research', 1),
#   ('prosecutor', 1),
#   ('cigarett', 1),
#   ('appeal', 1),
#   ('district', 1),
#   ('columbia', 1),
#   ('legisl', 1),
#   ('infiltr', 1),
#   ('busi', 1),
#   ('public', 1),
#   ('landmark', 1),
#   ('settlement', 1),
#   ('gain', 1),
#   ('aston', 1),
#   ('chelsea', 1),
#   ('knock', 1),
#   ('match', 1),
#   ('holland', 1),
#   ('action', 1),
#   ('challeng', 1),
#   ('boss', 1),
#   ('david', 1),
#   ('season', 1),
#   ('shortag', 1),
#   ('fit', 1),
#   ('dariu', 1),
#   ('russel', 1),
#   ('emerg', 1),
#   ('luke', 1),
#   ('moor', 1),
#   ('manag', 1),
#   ('depart', 1),
#   ('home', 1),
#   ('june', 1),
#   ('way', 1),
#   ('warn', 1),
#   ('downturn', 1),
#   ('barclay', 1),
#   ('norwich', 1),
#   ('homeown', 1),
#   ('key', 1),
#   ('pace', 1),
#   ('persist', 1),
#   ('rang', 1),
#   ('evid', 1),
#   ('rebound', 1),
#   ('tuesday', 1),
#   ('deliveri', 1),
#   ('part', 1),
#   ('day', 1),
#   ('achil', 1),
#   ('heel', 1),
#   ('john', 1),
#   ('bradi', 1),
#   ('northeast', 1),
#   ('blast', 1),
#   ('record', 1),
#   ('attack', 1),
#   ('riyadh', 1),
#   ('capit', 1),
#   ('saudi', 1),
#   ('arabia', 1),
#   ('briefli', 1),
#   ('suppli', 1),
#   ('chain', 1),
#   ('world', 1),
#   ('energi', 1),
#   ('secur', 1),
#   ('pari', 1)],
#  [('peopl', 16),
#   ('film', 16),
#   ('ranger', 14),
#   ('gorg', 14),
#   ('project', 12),
#   ('children', 12),
#   ('wale', 12),
#   ('health', 11),
#   ('ferguson', 10),
#   ('construct', 10),
#   ('year', 10),
#   ('order', 9),
#   ('broadband', 9),
#   ('servic', 9),
#   ('princ', 9),
#   ('blackburn', 8),
#   ('william', 8),
#   ('dam', 8),
#   ('china', 8),
#   ('school', 8),
#   ('charl', 8),
#   ('parker', 8),
#   ('list', 8),
#   ('gibbon', 8),
#   ('butt', 8),
#   ('time', 7),
#   ('govern', 7),
#   ('month', 7),
#   ('line', 7),
#   ('bowl', 7),
#   ('minist', 7),
#   ('transfer', 6),
#   ('agreement', 6),
#   ('offer', 6),
#   ('deal', 6),
#   ('firm', 6),
#   ('news', 6),
#   ('power', 6),
#   ('day', 6),
#   ('england', 6),
#   ('club', 5),
#   ('sister', 5),
#   ('capac', 5),
#   ('us', 5),
#   ('connect', 5),
#   ('mr', 5),
#   ('job', 5),
#   ('rover', 4),
#   ('bid', 4),
#   ('midfield', 4),
#   ('dialogu', 4),
#   ('park', 4),
#   ('window', 4),
#   ('player', 4),
#   ('corp', 4),
#   ('state', 4),
#   ('work', 4),
#   ('beij', 4),
#   ('plant', 4),
#   ('law', 4),
#   ('electr', 4),
#   ('group', 4),
#   ('star', 4),
#   ('rate', 4),
#   ('phone', 4),
#   ('coupl', 4),
#   ('staff', 4),
#   ('scotland', 3),
#   ('bic', 3),
#   ('execut', 3),
#   ('john', 3),
#   ('return', 3),
#   ('comment', 3),
#   ('way', 3),
#   ('thing', 3),
#   ('cup', 3),
#   ('win', 3),
#   ('injuri', 3),
#   ('compani', 3),
#   ('countri', 3),
#   ('gener', 3),
#   ('reach', 3),
#   ('critic', 3),
#   ('luca', 3),
#   ('knee', 3),
#   ('problem', 3),
#   ('speed', 3),
#   ('number', 3),
#   ('figur', 3),
#   ('germani', 3),
#   ('berlin', 3),
#   ('member', 3),
#   ('leaflet', 3),
#   ('respons', 3),
#   ('univers', 3),
#   ('engag', 3),
#   ('issu', 3),
#   ('leader', 3),
#   ('hospit', 3),
#   ('prof', 3),
#   ('polici', 3),
#   ('assembl', 3),
#   ('captain', 2),
#   ('barri', 2),
#   ('sport', 2),
#   ('request', 2),
#   ('wood', 2),
#   ('fee', 2),
#   ('thursday', 2),
#   ('propos', 2),
#   ('negoti', 2),
#   ('midnight', 2),
#   ('monday', 2),
#   ('winter', 2),
#   ('shut', 2),
#   ('close', 2),
#   ('chanc', 2),
#   ('glasgow', 2),
#   ('ball', 2),
#   ('court', 2),
#   ('moment', 2),
#   ('everyon', 2),
#   ('weekend', 2),
#   ('move', 2),
#   ('godson', 2),
#   ('colchest', 2),
#   ('mark', 2),
#   ('hugh', 2),
#   ('press', 2),
#   ('builder', 2),
#   ('halt', 2),
#   ('lack', 2),
#   ('check', 2),
#   ('suppli', 2),
#   ('protect', 2),
#   ('agenc', 2),
#   ('impact', 2),
#   ('assess', 2),
#   ('week', 2),
#   ('regul', 2),
#   ('corpor', 2),
#   ('accord', 2),
#   ('sep', 2),
#   ('economi', 2),
#   ('energi', 2),
#   ('shortag', 2),
#   ('factori', 2),
#   ('river', 2),
#   ('sand', 2),
#   ('yangtz', 2),
#   ('downstream', 2),
#   ('right', 2),
#   ('activist', 2),
#   ('movi', 2),
#   ('georg', 2),
#   ('show', 2),
#   ('reveng', 2),
#   ('programm', 2),
#   ('pm', 2),
#   ('doubt', 2),
#   ('play', 2),
#   ('report', 2),
#   ('quarter', 2),
#   ('growth', 2),
#   ('name', 2),
#   ('increas', 2),
#   ('custom', 2),
#   ('exchang', 2),
#   ('call', 2),
#   ('voic', 2),
#   ('resist', 2),
#   ('festiv', 2),
#   ('adolf', 2),
#   ('hitler', 2),
#   ('director', 2),
#   ('rosamund', 2),
#   ('trial', 2),
#   ('appear', 2),
#   ('carmen', 2),
#   ('nation', 2),
#   ('camilla', 2),
#   ('titl', 2),
#   ('ceremoni', 2),
#   ('windsor', 2),
#   ('poll', 2),
#   ('briton', 2),
#   ('decis', 2),
#   ('think', 2),
#   ('marriag', 2),
#   ('archbishop', 2),
#   ('canterburi', 2),
#   ('congratul', 2),
#   ('howard', 2),
#   ('democrat', 2),
#   ('event', 2),
#   ('commission', 2),
#   ('matter', 2),
#   ('opinion', 2),
#   ('experi', 2),
#   ('lesson', 2),
#   ('place', 2),
#   ('cymru', 2),
#   ('agenda', 2),
#   ('period', 2),
#   ('consolid', 2),
#   ('chang', 2),
#   ('treatment', 2),
#   ('map', 2),
#   ('morgan', 2),
#   ('reshuffl', 2),
#   ('minut', 1),
#   ('violent', 1),
#   ('seri', 1),
#   ('lb', 1),
#   ('sunday', 1),
#   ('parent', 1),
#   ('scene', 1),
#   ('guidanc', 1),
#   ('except', 1),
#   ('attack', 1),
#   ('clone', 1),
#   ('prequel', 1),
#   ('transform', 1),
#   ('heroic', 1),
#   ('manakin', 1),
#   ('skywalk', 1),
#   ('darth', 1),
#   ('vader', 1),
#   ('planet', 1),
#   ('volcano', 1),
#   ('lava', 1),
#   ('pact', 1),
#   ('devil', 1),
#   ('tragedi', 1),
#   ('hope', 1),
#   ('manchest', 1),
#   ('striker', 1),
#   ('ole', 1),
#   ('gunnar', 1),
#   ('season', 1),
#   ('surgeri', 1),
#   ('sweden', 1),
#   ('august', 1),
#   ('cartilag', 1),
#   ('substitut', 1),
#   ('contract', 1),
#   ('run', 1),
#   ('premier', 1),
#   ('leagu', 1),
#   ('britain', 1),
#   ('whole', 1),
#   ('europ', 1),
#   ('industri', 1),
#   ('watchdog', 1),
#   ('term', 1),
#   ('user', 1),
#   ('total', 1),
#   ('translat', 1),
#   ('netherland', 1),
#   ('direct', 1),
#   ('part', 1),
#   ('surg', 1),
#   ('subscrib', 1),
#   ('technolog', 1),
#   ('let', 1),
#   ('copper', 1),
#   ('data', 1),
#   ('breakthrough', 1),
#   ('demand', 1),
#   ('area', 1),
#   ('paul', 1),
#   ('reynold', 1),
#   ('net', 1),
#   ('telecommun', 1),
#   ('complet', 1),
#   ('influenc', 1),
#   ('sector', 1),
#   ('loop', 1),
#   ('bundl', 1),
#   ('rival', 1),
#   ('hardwar', 1),
#   ('home', 1),
#   ('offic', 1),
#   ('cabl', 1),
#   ('wireless', 1),
#   ('nil', 1),
#   ('million', 1),
#   ('septemb', 1),
#   ('carrier', 1),
#   ('talk', 1),
#   ('tel', 1),
#   ('network', 1),
#   ('cp', 1),
#   ('percentag', 1),
#   ('cheer', 1),
#   ('heroin', 1),
#   ('applaus', 1),
#   ('sophi', 1),
#   ('movement', 1),
#   ('brother', 1),
#   ('tyranni', 1),
#   ('marc', 1),
#   ('feel', 1),
#   ('legaci', 1),
#   ('idea', 1),
#   ('transcript', 1),
#   ('interrog', 1),
#   ('archiv', 1),
#   ('polic', 1),
#   ('discoveri', 1),
#   ('inspir', 1),
#   ('rel', 1),
#   ('accuraci', 1),
#   ('summer', 1),
#   ('arrest', 1),
#   ('charg', 1),
#   ('prize', 1),
#   ('version', 1),
#   ('bizet', 1),
#   ('opera', 1),
#   ('cape', 1),
#   ('town', 1),
#   ('xhosa', 1),
#   ('languag', 1),
#   ('township', 1),
#   ('stori', 1),
#   ('music', 1),
#   ('troup', 1),
#   ('debut', 1),
#   ('perform', 1),
#   ('featur', 1),
#   ('bear', 1),
#   ('award', 1),
#   ('watch', 1),
#   ('mood', 1),
#   ('reaction', 1),
#   ('april', 1),
#   ('duchess', 1),
#   ('cornwal', 1),
#   ('telegraph', 1),
#   ('suggest', 1),
#   ('consort', 1),
#   ('believ', 1),
#   ('major', 1),
#   ('monarchi', 1),
#   ('throne', 1),
#   ('grandson', 1),
#   ('death', 1),
#   ('abdic', 1),
#   ('night', 1),
#   ('dinner', 1),
#   ('diamond', 1),
#   ('famili', 1),
#   ('heirloom', 1),
#   ('specul', 1),
#   ('relationship', 1),
#   ('queen', 1),
#   ('duke', 1),
#   ('edinburgh', 1),
#   ('harri', 1),
#   ('luck', 1),
#   ('futur', 1),
#   ('wed', 1),
#   ('prayer', 1),
#   ('dedic', 1),
#   ('st', 1),
#   ('chapel', 1),
#   ('rowan', 1),
#   ('husband', 1),
#   ('governor', 1),
#   ('church', 1),
#   ('anglican', 1),
#   ('remarriag', 1),
#   ('divorce', 1),
#   ('divorc', 1),
#   ('diana', 1),
#   ('disappoint', 1),
#   ('sens', 1),
#   ('disillusion', 1),
#   ('coward', 1),
#   ('biographi', 1),
#   ('princess', 1),
#   ('step', 1),
#   ('blair', 1),
#   ('michael', 1),
#   ('trust', 1),
#   ('clarenc', 1),
#   ('hous', 1),
#   ('pain', 1),
#   ('street', 1),
#   ('professor', 1),
#   ('child', 1),
#   ('budget', 1),
#   ('interest', 1),
#   ('depart', 1),
#   ('live', 1),
#   ('valu', 1),
#   ('educ', 1),
#   ('secretari', 1),
#   ('ruth', 1),
#   ('lectur', 1),
#   ('guy', 1),
#   ('colleg', 1),
#   ('oxford', 1),
#   ('switzerland', 1),
#   ('grandfath', 1),
#   ('ireland', 1),
#   ('jane', 1),
#   ('challeng', 1),
#   ('essenti', 1),
#   ('record', 1),
#   ('valley', 1),
#   ('abort', 1),
#   ('length', 1),
#   ('associ', 1),
#   ('despair', 1),
#   ('radio', 1),
#   ('lot', 1),
#   ('popul', 1),
#   ('view', 1),
#   ('prioriti', 1),
#   ('approach', 1),
#   ('patient', 1),
#   ('test', 1),
#   ('reform', 1),
#   ('everyth', 1),
#   ('foundat', 1),
#   ('predecessor', 1),
#   ('rest', 1),
#   ('opposit', 1),
#   ('remov', 1),
#   ('rhode', 1),
#   ('elect', 1),
#   ('bevan', 1),
#   ('anybodi', 1),
#   ('morn', 1),
#   ('jone', 1),
#   ('deckchair', 1),
#   ('sink', 1),
#   ('dirti', 1),
#   ('lib', 1),
#   ('purpos', 1),
#   ('flak', 1),
#   ('invest', 1),
#   ('welsh', 1),
#   ('corner', 1)],
#  [('player', 18),
#   ('coach', 18),
#   ('connor', 15),
#   ('relationship', 12),
#   ('kid', 12),
#   ('week', 10),
#   ('wilkinson', 9),
#   ('number', 9),
#   ('jimmi', 9),
#   ('practic', 9),
#   ('game', 8),
#   ('england', 8),
#   ('year', 8),
#   ('someth', 7),
#   ('lion', 6),
#   ('tenni', 6),
#   ('perform', 6),
#   ('camp', 6),
#   ('manga', 6),
#   ('passion', 6),
#   ('injuri', 6),
#   ('farrel', 5),
#   ('rugbi', 5),
#   ('captain', 5),
#   ('john', 5),
#   ('club', 5),
#   ('world', 5),
#   ('site', 5),
#   ('director', 5),
#   ('hendrix', 5),
#   ('hous', 5),
#   ('britain', 4),
#   ('way', 4),
#   ('bic', 4),
#   ('union', 4),
#   ('henson', 4),
#   ('stake', 4),
#   ('home', 4),
#   ('hand', 4),
#   ('wale', 4),
#   ('jason', 4),
#   ('itali', 4),
#   ('intern', 4),
#   ('guitarist', 4),
#   ('leagu', 3),
#   ('stage', 3),
#   ('well', 3),
#   ('problem', 3),
#   ('month', 3),
#   ('saracen', 3),
#   ('back', 3),
#   ('row', 3),
#   ('bristol', 3),
#   ('jone', 3),
#   ('shirt', 3),
#   ('charli', 3),
#   ('dodgson', 3),
#   ('robinson', 3),
#   ('lawn', 3),
#   ('associ', 3),
#   ('tim', 3),
#   ('spent', 3),
#   ('day', 3),
#   ('elit', 3),
#   ('winter', 3),
#   ('attitud', 3),
#   ('arrang', 3),
#   ('execut', 3),
#   ('brother', 3),
#   ('begin', 3),
#   ('host', 3),
#   ('greg', 3),
#   ('redskin', 3),
#   ('parma', 3),
#   ('ann', 3),
#   ('bunch', 3),
#   ('london', 3),
#   ('workout', 3),
#   ('feel', 3),
#   ('desir', 3),
#   ('import', 3),
#   ('work', 3),
#   ('effort', 3),
#   ('minut', 3),
#   ('david', 3),
#   ('relat', 3),
#   ('sport', 3),
#   ('get', 3),
#   ('word', 3),
#   ('job', 3),
#   ('life', 3),
#   ('input', 3),
#   ('reput', 3),
#   ('wimbledon', 3),
#   ('tournament', 3),
#   ('museum', 3),
#   ('author', 3),
#   ('tiger', 2),
#   ('leicest', 2),
#   ('andi', 2),
#   ('moment', 2),
#   ('situat', 2),
#   ('gambl', 2),
#   ('knee', 2),
#   ('oper', 2),
#   ('forward', 2),
#   ('option', 2),
#   ('eye', 2),
#   ('zealand', 2),
#   ('xiv', 2),
#   ('arrog', 2),
#   ('wait', 2),
#   ('defenc', 2),
#   ('custer', 2),
#   ('armi', 2),
#   ('ball', 2),
#   ('fit', 2),
#   ('return', 2),
#   ('edinburgh', 2),
#   ('bicep', 2),
#   ('octob', 2),
#   ('part', 2),
#   ('falcon', 2),
#   ('wednesday', 2),
#   ('match', 2),
#   ('bench', 2),
#   ('rob', 2),
#   ('andrew', 2),
#   ('autumn', 2),
#   ('haematoma', 2),
#   ('arm', 2),
#   ('sale', 2),
#   ('canada', 2),
#   ('south', 2),
#   ('africa', 2),
#   ('muscl', 2),
#   ('sidelin', 2),
#   ('shoulder', 2),
#   ('cup', 2),
#   ('father', 2),
#   ('seattl', 2),
#   ('mayor', 2),
#   ('foundat', 2),
#   ('build', 2),
#   ('goldman', 2),
#   ('bid', 1),
#   ('decid', 1),
#   ('code', 1),
#   ('anybodi', 1),
#   ('process', 1),
#   ('radio', 1),
#   ('lot', 1),
#   ('unknown', 1),
#   ('whoever', 1),
#   ('list', 1),
#   ('step', 1),
#   ('centr', 1),
#   ('posit', 1),
#   ('use', 1),
#   ('skill', 1),
#   ('juri', 1),
#   ('divid', 1),
#   ('balanc', 1),
#   ('cost', 1),
#   ('bring', 1),
#   ('replac', 1),
#   ('nation', 1),
#   ('prize', 1),
#   ('trip', 1),
#   ('summer', 1),
#   ('claim', 1),
#   ('place', 1),
#   ('start', 1),
#   ('weekend', 1),
#   ('interview', 1),
#   ('afterward', 1),
#   ('confid', 1),
#   ('element', 1),
#   ('touch', 1),
#   ('pair', 1),
#   ('heel', 1),
#   ('kick', 1),
#   ('penalti', 1),
#   ('test', 1),
#   ('midfield', 1),
#   ('direct', 1),
#   ('gener', 1),
#   ('side', 1),
#   ('johnni', 1),
#   ('grab', 1),
#   ('team', 1),
#   ('bet', 1),
#   ('prop', 1),
#   ('jenkin', 1),
#   ('victori', 1),
#   ('frame', 1),
#   ('caus', 1),
#   ('harm', 1),
#   ('joe', 1),
#   ('wors', 1),
#   ('josh', 1),
#   ('noth', 1),
#   ('wrong', 1),
#   ('mathew', 1),
#   ('scot', 1),
#   ('franc', 1),
#   ('smith', 1),
#   ('like', 1),
#   ('chri', 1),
#   ('mark', 1),
#   ('hogg', 1),
#   ('coupl', 1),
#   ('run', 1),
#   ('star', 1),
#   ('ireland', 1),
#   ('win', 1),
#   ('look', 1),
#   ('certainti', 1),
#   ('brian', 1),
#   ('class', 1),
#   ('act', 1),
#   ('line', 1),
#   ('break', 1),
#   ('combin', 1),
#   ('cornel', 1),
#   ('edg', 1),
#   ('malcolm', 1),
#   ('shane', 1),
#   ('born', 1),
#   ('charact', 1),
#   ('bit', 1),
#   ('pack', 1),
#   ('impress', 1),
#   ('half', 1),
#   ('possess', 1),
#   ('plan', 1),
#   ('propos', 1),
#   ('support', 1),
#   ('jim', 1),
#   ('rae', 1),
#   ('marshal', 1),
#   ('jame', 1),
#   ('land', 1),
#   ('citi', 1),
#   ('plot', 1),
#   ('develop', 1),
#   ('deadlin', 1),
#   ('februari', 1),
#   ('commun', 1),
#   ('offici', 1),
#   ('deal', 1),
#   ('properti', 1),
#   ('franklin', 1),
#   ('chief', 1),
#   ('depart', 1),
#   ('perspect', 1),
#   ('district', 1),
#   ('jani', 1),
#   ('stepsist', 1),
#   ('famili', 1),
#   ('road', 1),
#   ('everyth', 1),
#   ('time', 1),
#   ('drug', 1),
#   ('overdos', 1),
#   ('age', 1)],
#  [('break', 28),
#   ('robinson', 21),
#   ('leagu', 17),
#   ('dodgson', 16),
#   ('england', 16),
#   ('winter', 12),
#   ('player', 12),
#   ('australia', 12),
#   ('britain', 12),
#   ('premiership', 10),
#   ('champion', 10),
#   ('team', 10),
#   ('game', 10),
#   ('chanc', 9),
#   ('year', 9),
#   ('code', 9),
#   ('rugbi', 9),
#   ('footbal', 8),
#   ('side', 8),
#   ('match', 7),
#   ('lot', 7),
#   ('countri', 7),
#   ('strength', 6),
#   ('success', 6),
#   ('union', 6),
#   ('aussi', 6),
#   ('victori', 6),
#   ('autumn', 6),
#   ('card', 6),
#   ('today', 5),
#   ('clash', 4),
#   ('europ', 4),
#   ('batteri', 4),
#   ('advantag', 4),
#   ('enthusiasm', 4),
#   ('energi', 4),
#   ('time', 4),
#   ('club', 4),
#   ('week', 4),
#   ('day', 4),
#   ('level', 4),
#   ('market', 4),
#   ('recoveri', 4),
#   ('share', 4),
#   ('busi', 4),
#   ('month', 4),
#   ('confid', 4),
#   ('japan', 4),
#   ('captain', 3),
#   ('jason', 3),
#   ('lead', 3),
#   ('twickenham', 3),
#   ('get', 3),
#   ('tournament', 3),
#   ('achiev', 3),
#   ('win', 3),
#   ('canada', 3),
#   ('south', 3),
#   ('africa', 3),
#   ('reveng', 3),
#   ('june', 3),
#   ('wallabi', 3),
#   ('failur', 3),
#   ('leland', 3),
#   ('road', 3),
#   ('test', 3),
#   ('silverwar', 3),
#   ('ash', 3),
#   ('opportun', 3),
#   ('trophi', 3),
#   ('boost', 3),
#   ('boy', 3),
#   ('sight', 3),
#   ('task', 3),
#   ('novemb', 3),
#   ('seri', 3),
#   ('regret', 3),
#   ('luck', 3),
#   ('messag', 3),
#   ('showdown', 3),
#   ('leed', 3),
#   ('email', 3),
#   ('everyon', 3),
#   ('guy', 3),
#   ('relish', 2),
#   ('blackburn', 2),
#   ('boss', 2),
#   ('roy', 2),
#   ('rest', 2),
#   ('schedul', 2),
#   ('bid', 2),
#   ('glori', 2),
#   ('charg', 2),
#   ('stavang', 2),
#   ('bayer', 2),
#   ('lederhosen', 2),
#   ('enfield', 2),
#   ('tuesday', 2),
#   ('member', 2),
#   ('committe', 2),
#   ('advoc', 2),
#   ('contend', 2),
#   ('fixtur', 2),
#   ('list', 2),
#   ('bic', 2),
#   ('sport', 2),
#   ('idea', 2),
#   ('repres', 2),
#   ('certainti', 2),
#   ('edg', 2),
#   ('support', 2),
#   ('season', 2),
#   ('school', 2),
#   ('thought', 2),
#   ('disadvantag', 2),
#   ('discuss', 2),
#   ('natur', 2),
#   ('need', 2),
#   ('way', 2),
#   ('manag', 2),
#   ('call', 2),
#   ('introduct', 2),
#   ('toward', 2),
#   ('plenti', 2),
#   ('thing', 2),
#   ('length', 2),
#   ('itali', 2),
#   ('christma', 2),
#   ('anyth', 2),
#   ('fit', 2),
#   ('programm', 2),
#   ('stay', 2),
#   ('step', 2),
#   ('demand', 2),
#   ('premier', 2),
#   ('world', 2),
#   ('physic', 2),
#   ('stock', 2),
#   ('eye', 2),
#   ('juli', 2),
#   ('hope', 2),
#   ('index', 2),
#   ('point', 2),
#   ('morgan', 2),
#   ('equiti', 2),
#   ('strategist', 2),
#   ('optim', 2),
#   ('pessim', 2),
#   ('commun', 2),
#   ('lankan', 2),
#   ('survey', 2),
#   ('manufactur', 2),
#   ('march', 2),
#   ('growth', 2),
#   ('oil', 2),
#   ('price', 2),
#   ('yen', 2),
#   ('export', 2),
#   ('fall', 2),
#   ('trader', 2),
#   ('economi', 2),
#   ('recess', 2),
#   ('reform', 2),
#   ('bank', 2),
#   ('sector', 2),
#   ('debt', 2),
#   ('problem', 2)],
#  [('parti', 25),
#   ('answer', 20),
#   ('lord', 20),
#   ('hagu', 18),
#   ('goldsmith', 14),
#   ('advic', 14),
#   ('peopl', 13),
#   ('attorney', 12),
#   ('call', 12),
#   ('rule', 9),
#   ('govern', 8),
#   ('opinion', 8),
#   ('statement', 8),
#   ('minist', 8),
#   ('summari', 8),
#   ('blair', 8),
#   ('action', 7),
#   ('gener', 6),
#   ('street', 6),
#   ('text', 6),
#   ('common', 6),
#   ('paper', 6),
#   ('tori', 6),
#   ('offici', 6),
#   ('question', 6),
#   ('member', 6),
#   ('ambit', 6),
#   ('leader', 6),
#   ('front', 6),
#   ('intent', 6),
#   ('market', 6),
#   ('view', 5),
#   ('vote', 5),
#   ('way', 5),
#   ('offic', 5),
#   ('secretari', 5),
#   ('occas', 5),
#   ('tip', 5),
#   ('map', 4),
#   ('labour', 4),
#   ('role', 4),
#   ('chancellor', 4),
#   ('intellig', 4),
#   ('week', 4),
#   ('secur', 4),
#   ('resolut', 4),
#   ('time', 4),
#   ('mate', 4),
#   ('book', 4),
#   ('march', 4),
#   ('william', 4),
#   ('leadership', 4),
#   ('polit', 4),
#   ('bench', 4),
#   ('feel', 4),
#   ('pension', 4),
#   ('winter', 4),
#   ('watchdog', 4),
#   ('telephon', 4),
#   ('voter', 4),
#   ('news', 3),
#   ('issu', 3),
#   ('elect', 3),
#   ('thing', 3),
#   ('energi', 3),
#   ('year', 3),
#   ('insul', 3),
#   ('list', 3),
#   ('inform', 3),
#   ('commission', 3),
#   ('number', 3),
#   ('jone', 3),
#   ('case', 2),
#   ('iraq', 2),
#   ('legal', 2),
#   ('stormi', 2),
#   ('exchang', 2),
#   ('eve', 2),
#   ('invas', 2),
#   ('willing', 2),
#   ('conflict', 2),
#   ('confidenti', 2),
#   ('hous', 2),
#   ('mckay', 2),
#   ('suggest', 2),
#   ('peer', 2),
#   ('snide', 2),
#   ('suspicion', 2),
#   ('consumpt', 2),
#   ('dossier', 2),
#   ('weapon', 2),
#   ('mass', 2),
#   ('destruct', 2),
#   ('draft', 2),
#   ('process', 2),
#   ('cours', 2),
#   ('involv', 2),
#   ('solicitor', 2),
#   ('herman', 2),
#   ('pc', 2),
#   ('christoph', 2),
#   ('greenwood', 2),
#   ('irvin', 2),
#   ('council', 2),
#   ('robin', 2),
#   ('cook', 2),
#   ('admiss', 2),
#   ('parliament', 2),
#   ('today', 2),
#   ('accur', 2),
#   ('toni', 2),
#   ('confer', 2),
#   ('michael', 2),
#   ('committe', 2),
#   ('part', 2),
#   ('butler', 2),
#   ('inquiri', 2),
#   ('bic', 2),
#   ('absolut', 2),
#   ('princ', 2),
#   ('charl', 2),
#   ('marriag', 2),
#   ('convent', 2),
#   ('interest', 2),
#   ('sand', 2),
#   ('cheri', 2),
#   ('matrix', 2),
#   ('chamber', 2),
#   ('posit', 2),
#   ('telegraph', 2),
#   ('life', 2),
#   ('defeat', 2),
#   ('return', 2),
#   ('york', 2),
#   ('famili', 2),
#   ('wife', 2),
#   ('union', 2),
#   ('biographi', 2),
#   ('younger', 2),
#   ('newspap', 2),
#   ('determin', 2),
#   ('tim', 2),
#   ('educ', 2),
#   ('boost', 2),
#   ('opposit', 2),
#   ('fortun', 2),
#   ('age', 2),
#   ('career', 2),
#   ('cabinet', 2),
#   ('voucher', 2),
#   ('democrat', 2),
#   ('plan', 2),
#   ('fuel', 2),
#   ('payment', 2),
#   ('demo', 2),
#   ('discount', 2),
#   ('home', 2),
#   ('scheme', 2),
#   ('conserv', 2),
#   ('lib', 2),
#   ('prefer', 2),
#   ('servic', 2),
#   ('law', 2),
#   ('regul', 2),
#   ('script', 2),
#   ('taylor', 2),
#   ('death', 1),
#   ('save', 1),
#   ('snow', 1),
#   ('temperatur', 1),
#   ('dave', 1),
#   ('approach', 1),
#   ('scandal', 1),
#   ('thousand', 1),
#   ('cold', 1),
#   ('suppli', 1),
#   ('busi', 1),
#   ('household', 1),
#   ('money', 1),
#   ('campaign', 1),
#   ('million', 1),
#   ('instanc', 1),
#   ('survey', 1),
#   ('data', 1),
#   ('centr', 1),
#   ('sale', 1),
#   ('associ', 1),
#   ('direct', 1),
#   ('privaci', 1),
#   ('commun', 1),
#   ('politician', 1),
#   ('sector', 1),
#   ('compani', 1),
#   ('spokesman', 1),
#   ('membership', 1),
#   ('fundrais', 1),
#   ('identif', 1),
#   ('spokeswoman', 1),
#   ('stuck', 1),
#   ('subscrib', 1),
#   ('line', 1),
#   ('assist', 1),
#   ('phil', 1),
#   ('research', 1),
#   ('poll', 1),
#   ('someon', 1),
#   ('record', 1),
#   ('futur', 1),
#   ('person', 1),
#   ('breach', 1),
#   ('complaint', 1),
#   ('chairman', 1),
#   ('phone', 1),
#   ('evid', 1),
#   ('countri', 1),
#   ('swift', 1),
#   ('guidelin', 1)],
#  [('telegraph', 16),
#   ('journalist', 14),
#   ('news', 14),
#   ('newspap', 12),
#   ('condor', 9),
#   ('group', 8),
#   ('print', 8),
#   ('compani', 8),
#   ('corp', 8),
#   ('share', 8),
#   ('fox', 7),
#   ('complet', 6),
#   ('reader', 6),
#   ('redund', 6),
#   ('page', 6),
#   ('scotland', 6),
#   ('ireland', 6),
#   ('bristol', 6),
#   ('injuri', 6),
#   ('replac', 6),
#   ('centr', 6),
#   ('armi', 6),
#   ('morgan', 6),
#   ('invest', 5),
#   ('revenu', 5),
#   ('job', 4),
#   ('staff', 4),
#   ('cut', 4),
#   ('facil', 4),
#   ('advertis', 4),
#   ('union', 4),
#   ('manag', 4),
#   ('strike', 4),
#   ('time', 4),
#   ('fitzpatrick', 4),
#   ('consult', 4),
#   ('titl', 4),
#   ('format', 4),
#   ('circul', 4),
#   ('colour', 4),
#   ('month', 4),
#   ('year', 3),
#   ('busi', 3),
#   ('media', 3),
#   ('game', 3),
#   ('captain', 3),
#   ('re', 3),
#   ('nation', 3),
#   ('start', 3),
#   ('win', 3),
#   ('morn', 3),
#   ('fellow', 3),
#   ('gordon', 3),
#   ('test', 3),
#   ('friday', 3),
#   ('mag', 3),
#   ('shane', 3),
#   ('bowl', 3),
#   ('squad', 3),
#   ('measur', 3),
#   ('chang', 3),
#   ('side', 3),
#   ('flanker', 3),
#   ('johnni', 3),
#   ('deni', 3),
#   ('cap', 3),
#   ('debut', 3),
#   ('victori', 3),
#   ('south', 3),
#   ('murphi', 3),
#   ('vicki', 3),
#   ('gari', 3),
#   ('stringer', 3),
#   ('foley', 3),
#   ('sherman', 3),
#   ('miller', 3),
#   ('humphrey', 3),
#   ('offer', 3),
#   ('entertain', 3),
#   ('firm', 2),
#   ('afternoon', 2),
#   ('surpris', 2),
#   ('announc', 2),
#   ('background', 2),
#   ('notic', 2),
#   ('midday', 2),
#   ('monday', 2),
#   ('face', 2),
#   ('ballot', 2),
#   ('pearson', 2),
#   ('week', 2),
#   ('report', 2),
#   ('procedur', 2),
#   ('teeth', 2),
#   ('peopl', 2),
#   ('jeremi', 2),
#   ('dear', 2),
#   ('secretari', 2),
#   ('nut', 2),
#   ('offici', 2),
#   ('barri', 2),
#   ('period', 2),
#   ('disregard', 2),
#   ('right', 2),
#   ('member', 2),
#   ('broadsheet', 2),
#   ('declin', 2),
#   ('plan', 2),
#   ('rise', 2),
#   ('size', 2),
#   ('guardian', 2),
#   ('bet', 2),
#   ('europ', 2),
#   ('barclay', 2),
#   ('david', 2),
#   ('lord', 2),
#   ('conrad', 2),
#   ('brother', 2),
#   ('sale', 2),
#   ('execut', 2),
#   ('murdoch', 2),
#   ('mclean', 2),
#   ('lifeblood', 2),
#   ('qualiti', 2),
#   ('action', 2),
#   ('product', 2),
#   ('capabl', 2),
#   ('machineri', 2),
#   ('case', 2),
#   ('public', 2),
#   ('unit', 2),
#   ('sun', 2),
#   ('world', 2),
#   ('triniti', 2),
#   ('mirror', 2),
#   ('mail', 2),
#   ('trust', 2),
#   ('plant', 2),
#   ('minor', 2),
#   ('investor', 2),
#   ('centuri', 2),
#   ('film', 2),
#   ('move', 2),
#   ('decis', 2),
#   ('cent', 2),
#   ('corpor', 1),
#   ('broadcast', 1),
#   ('subsidiari', 1),
#   ('home', 1),
#   ('televis', 1),
#   ('network', 1),
#   ('studio', 1),
#   ('releas', 1),
#   ('heart', 1),
#   ('maccabe', 1),
#   ('robot', 1),
#   ('seri', 1),
#   ('term', 1),
#   ('sharehold', 1),
#   ('return', 1),
#   ('analyst', 1),
#   ('york', 1),
#   ('need', 1),
#   ('stock', 1),
#   ('market', 1),
#   ('octob', 1),
#   ('transfer', 1),
#   ('domicil', 1),
#   ('australia', 1),
#   ('state', 1),
#   ('delawar', 1),
#   ('attract', 1),
#   ('institut', 1),
#   ('capit', 1)]]

# %%
len(word_counts)
# Out:
# 10

# %%
word_counts[0]
# Out:
# [('year', 40),
#  ('govern', 37),
#  ('film', 36),
#  ('life', 27),
#  ('club', 26),
#  ('music', 26),
#  ('share', 24),
#  ('parti', 21),
#  ('money', 20),
#  ('drug', 20),
#  ('compani', 19),
#  ('invest', 19),
#  ('market', 19),
#  ('firm', 18),
#  ('peopl', 18),
#  ('sioux', 18),
#  ('part', 16),
#  ('stock', 16),
#  ('time', 15),
#  ('fund', 15),
#  ('award', 15),
#  ('polici', 15),
#  ('takeov', 14),
#  ('pm', 14),
#  ('school', 13),
#  ('deal', 13),
#  ('heart', 13),
#  ('rate', 13),
#  ('problem', 12),
#  ('bate', 12),
#  ('leed', 12),
#  ('stake', 12),
#  ('director', 12),
#  ('power', 12),
#  ('elect', 12),
#  ('risk', 12),
#  ('side', 12),
#  ('week', 11),
#  ('countri', 11),
#  ('herman', 11),
#  ('howard', 11),
#  ('educ', 10),
#  ('analyst', 10),
#  ('car', 10),
#  ('merck', 10),
#  ('term', 9),
#  ('board', 9),
#  ('month', 9),
#  ('debut', 9),
#  ('sale', 9),
#  ('world', 9),
#  ('way', 9),
#  ('match', 9),
#  ('pension', 9),
#  ('festiv', 9),
#  ('success', 8),
#  ('chelsea', 8),
#  ('peter', 8),
#  ('need', 8),
#  ('donat', 8),
#  ('report', 8),
#  ('state', 8),
#  ('level', 8),
#  ('seed', 8),
#  ('set', 8),
#  ('leader', 8),
#  ('sector', 8),
#  ('fiat', 8),
#  ('cut', 8),
#  ('job', 8),
#  ('cup', 8),
#  ('thursday', 8),
#  ('insur', 8),
#  ('bonu', 8),
#  ('inhibitor', 8),
#  ('patient', 8),
#  ('day', 7),
#  ('case', 7),
#  ('place', 7),
#  ('number', 7),
#  ('chairman', 7),
#  ('plan', 7),
#  ('propos', 7),
#  ('financ', 7),
#  ('game', 7),
#  ('soprano', 7),
#  ('musician', 7),
#  ('everyon', 7),
#  ('loss', 7),
#  ('commit', 7),
#  ('critic', 7),
#  ('famili', 6),
#  ('top', 6),
#  ('help', 6),
#  ('trainer', 6),
#  ('benefit', 6),
#  ('role', 6),
#  ('point', 6),
#  ('offer', 6),
#  ('effort', 6),
#  ('leagu', 6),
#  ('tax', 6),
#  ('record', 6),
#  ('prize', 6),
#  ('perform', 6),
#  ('industri', 6),
#  ('face', 6),
#  ('draw', 6),
#  ('manufactur', 6),
#  ('submiss', 6),
#  ('screen', 6),
#  ('fewer', 6),
#  ('bonus', 6),
#  ('policyhold', 6),
#  ('regul', 6),
#  ('painkil', 6),
#  ('attack', 6),
#  ('truant', 5),
#  ('pupil', 5),
#  ('parent', 5),
#  ('programm', 5),
#  ('figur', 5),
#  ('work', 5),
#  ('cours', 5),
#  ('debt', 5),
#  ('produc', 5),
#  ('commiss', 5),
#  ('research', 5),
#  ('race', 5),
#  ('group', 5),
#  ('servic', 5),
#  ('talent', 5),
#  ('thing', 5),
#  ('pop', 5),
#  ('right', 5),
#  ('product', 5),
#  ('confer', 5),
#  ('team', 5),
#  ('brighton', 5),
#  ('crew', 5),
#  ('trade', 5),
#  ('union', 5),
#  ('honour', 5),
#  ('claim', 5),
#  ('player', 5),
#  ('motorboat', 5),
#  ('interest', 5),
#  ('stroke', 5),
#  ('england', 4),
#  ('secretari', 4),
#  ('system', 4),
#  ('class', 4),
#  ('measur', 4),
#  ('author', 4),
#  ('child', 4),
#  ('offic', 4),
#  ('addit', 4),
#  ('premiership', 4),
#  ('everyth', 4),
#  ('sport', 4),
#  ('cash', 4),
#  ('light', 4),
#  ('march', 4),
#  ('period', 4),
#  ('capac', 4),
#  ('lorim', 4),
#  ('arrang', 4),
#  ('administr', 4),
#  ('flotat', 4),
#  ('india', 4),
#  ('cap', 4),
#  ('public', 4),
#  ('someth', 4),
#  ('politician', 4),
#  ('health', 4),
#  ('dubai', 4),
#  ('rain', 4),
#  ('break', 4),
#  ('control', 4),
#  ('start', 4),
#  ('championship', 4),
#  ('ferdinand', 4),
#  ('britain', 4),
#  ('area', 4),
#  ('live', 4),
#  ('deadlin', 4),
#  ('divis', 4),
#  ('unit', 4),
#  ('tuesday', 4),
#  ('option', 4),
#  ('europ', 4),
#  ('citi', 4),
#  ('weekend', 4),
#  ('visit', 4),
#  ('plymouth', 4),
#  ('liverpool', 4),
#  ('palac', 4),
#  ('afford', 4),
#  ('bolton', 4),
#  ('cardiff', 4),
#  ('preston', 4),
#  ('northampton', 4),
#  ('middlesbrough', 4),
#  ('read', 4),
#  ('wage', 4),
#  ('childcar', 4),
#  ('poverti', 4),
#  ('london', 4),
#  ('teenag', 4),
#  ('trophi', 4),
#  ('bit', 4),
#  ('rugbi', 4),
#  ('motorcycl', 4),
#  ('stanley', 4),
#  ('gear', 4),
#  ('news', 4),
#  ('return', 4),
#  ('profit', 4),
#  ('gill', 4),
#  ('food', 4),
#  ('panel', 4),
#  ('celeb', 4),
#  ('approv', 4),
#  ('ada', 4),
#  ('kim', 4),
#  ('inform', 4),
#  ('graham', 4),
#  ('safeti', 4),
#  ('diseas', 4),
#  ('immunis', 4),
#  ('mongrel', 4),
#  ('labour', 4),
#  ('today', 4),
#  ('penalti', 3),
#  ('notic', 3),
#  ('children', 3),
#  ('scheme', 3),
#  ('attend', 3),
#  ('truanci', 3),
#  ('hit', 3),
#  ('half', 3),
#  ('nation', 3),
#  ('lot', 3),
#  ('forward', 3),
#  ('road', 3),
#  ('chequ', 3),
#  ('discuss', 3),
#  ('wednesday', 3),
#  ('footbal', 3),
#  ('debat', 3),
#  ('donor', 3),
#  ('call', 3),
#  ('limit', 3),
#  ('futur', 3),
#  ('candid', 3),
#  ('campaign', 3),
#  ('taxpay', 3),
#  ('amount', 3),
#  ('differ', 3),
#  ('voter', 3),
#  ('spend', 3),
#  ('ivan', 3),
#  ('victori', 3),
#  ('weather', 3),
#  ('form', 3),
#  ('scott', 3),
#  ('indoor', 3),
#  ('circuit', 3),
#  ('scot', 3),
#  ('meet', 3),
#  ('brit', 3),
#  ('label', 3),
#  ('don', 3),
#  ('art', 3),
#  ('grant', 3),
#  ('valu', 3),
#  ('show', 3),
#  ('move', 3),
#  ('support', 3),
#  ('allianc', 3),
#  ('oper', 3),
#  ('arm', 3),
#  ('troubl', 3),
#  ('home', 3),
#  ('season', 3),
#  ('birmingham', 3),
#  ('action', 3),
#  ('strategi', 3),
#  ('hollywood', 3),
#  ('actor', 3),
#  ('kevin', 3),
#  ('bacon', 3),
#  ('paedophil', 3),
#  ('woodsman', 3),
#  ('strait', 3),
#  ('ray', 3),
#  ('kassel', 3),
#  ('jail', 3),
#  ('judg', 3),
#  ('subject', 3),
#  ('insight', 3),
#  ('sensit', 3),
#  ('boy', 3),
#  ('cri', 3),
#  ('stori', 3),
#  ('brandon', 3),
#  ('gamma', 3),
#  ('santa', 3),
#  ('featur', 3),
#  ('wale', 3),
#  ('mother', 3),
#  ('tens', 3),
#  ('neighbour', 3),
#  ('night', 3),
#  ('fire', 3),
#  ('handicap', 3),
#  ('sutherland', 3),
#  ('jonathan', 3),
#  ('cassett', 3),
#  ('tarnat', 3),
#  ('maccabe', 3),
#  ('jude', 3),
#  ('law', 3),
#  ('hoffman', 3),
#  ('king', 3),
#  ('par', 3),
#  ('anim', 3),
#  ('incred', 3),
#  ('bullet', 3),
#  ('rapper', 3),
#  ('asher', 3),
#  ('roger', 3),
#  ('chanc', 3),
#  ('seven', 3),
#  ('endeavour', 3),
#  ('technolog', 3),
#  ('display', 3),
#  ('bodi', 3),
#  ('clutch', 3),
#  ('pedal', 3),
#  ('earn', 3),
#  ('cost', 3),
#  ('speech', 3),
#  ('develop', 3),
#  ('main', 3),
#  ('opposit', 3),
#  ('anyth', 3),
#  ('contract', 2),
#  ('tori', 2),
#  ('issu', 2),
#  ('absenc', 2),
#  ('crime', 2),
#  ('forc', 2),
#  ('stanc', 2),
#  ('patrol', 2),
#  ('depart', 2),
#  ('seal', 2),
#  ('get', 2),
#  ('friday', 2),
#  ('mantel', 2),
#  ('guis', 2),
#  ('leland', 2),
#  ('stadium', 2),
#  ('thorp', 2),
#  ('arch', 2),
#  ('ground', 2),
#  ('jon', 2),
#  ('task', 2),
#  ('flow', 2),
#  ('sort', 2),
#  ('creditor', 2),
#  ('tunnel', 2),
#  ('matter', 2),
#  ('gerald', 2),
#  ('medium', 2),
#  ('surviv', 2),
#  ('date', 2),
#  ('percent', 2),
#  ('agreement', 2),
#  ('consortium', 2),
#  ('background', 2),
#  ('smooth', 2),
#  ('contact', 2),
#  ('mccormick', 2),
#  ('consult', 2),
#  ('loan', 2),
#  ('yvonn', 2),
#  ('todd', 2),
#  ('lawyer', 2),
#  ('mark', 2),
#  ('taylor', 2),
#  ('detail', 2),
#  ('person', 2),
#  ('roman', 2),
#  ('stamford', 2),
#  ('bridg', 2),
#  ('salisburi', 2),
#  ('brink', 2),
#  ('deduct', 2),
#  ('prospect', 2),
#  ('pc', 2),
#  ('mix', 2),
#  ('rupe', 2),
#  ('softwar', 2),
#  ('bet', 2),
#  ('economi', 2),
#  ('util', 2),
#  ('watchdog', 2),
#  ('gift', 2),
#  ('rule', 2),
#  ('principl', 2),
#  ('chang', 2),
#  ('relief', 2),
#  ('common', 2),
#  ('parliament', 2),
#  ('assembl', 2),
#  ('ireland', 2),
#  ('polit', 2),
#  ('tim', 2),
#  ('progress', 2),
#  ('win', 2),
#  ('fifth', 2),
#  ('tommi', 2),
#  ('roberto', 2),
#  ('liefer', 2),
#  ('germani', 2),
#  ('afterward', 2),
#  ('umpir', 2),
#  ('doe', 2),
#  ('score', 2),
#  ('irrelev', 2),
#  ('desert', 2),
#  ('advanc', 2),
#  ('kornberg', 2),
#  ('arriv', 2),
#  ('lectur', 2),
#  ('output', 2),
#  ('univers', 2),
#  ('event', 2),
#  ('seri', 2),
#  ('band', 2),
#  ('stereotyp', 2),
#  ('morn', 2),
#  ('hostil', 2),
#  ('toward', 2),
#  ('speaker', 2),
#  ('compos', 2),
#  ('appear', 2),
#  ('artist', 2),
#  ('licenc', 2),
#  ('pound', 2),
#  ('exampl', 2),
#  ('joy', 2),
#  ('sens', 2),
#  ('franz', 2),
#  ('facil', 2),
#  ('earth', 2),
#  ('line', 2),
#  ('hand', 2),
#  ('near', 2),
#  ('motor', 2),
#  ('disagr', 2),
#  ('talk', 2),
#  ('gain', 2),
#  ('hope', 2),
#  ('payoff', 2),
#  ('decis', 2),
#  ('halv', 2),
#  ('outright', 2),
#  ('giant', 2),
#  ('godfath', 2),
#  ('put', 2),
#  ('saab', 2),
#  ('manag', 2),
#  ('patrick', 2),
#  ('auto', 2),
#  ('bank', 2),
#  ('newcastl', 2),
#  ('trip', 2),
#  ('highlight', 2),
#  ('slough', 2),
#  ('round', 2),
#  ('doncast', 2),
#  ('saturday', 2),
#  ('strafford', 2),
#  ('holder', 2),
#  ('arsen', 2),
#  ('host', 2),
#  ('brantford', 2),
#  ('sunday', 2),
#  ('replay', 2),
#  ('martin', 2),
#  ('griffin', 2),
#  ('park', 2),
#  ('travel', 2),
#  ('villa', 2),
#  ('sheffield', 2),
#  ('struggl', 2),
#  ('carl', 2),
#  ('counti', 2),
#  ('spur', 2),
#  ('hart', 2),
#  ('lane', 2),
#  ('exet', 2),
#  ('leicest', 2),
#  ('blackpool', 2),
#  ('sunderland', 2),
#  ('wolv', 2),
#  ('hull', 2),
#  ('colchest', 2),
#  ('nottingham', 2),
#  ('boston', 2),
#  ('milton', 2),
#  ('keyn', 2),
#  ('oldham', 2),
#  ('charlton', 2),
#  ('rochdal', 2),
#  ('shelf', 2),
#  ('aston', 2),
#  ('west', 2),
#  ('evil', 2),
#  ('burnley', 2),
#  ('bournemouth', 2),
#  ('chester', 2),
#  ('coventri', 2),
#  ('durham', 2),
#  ('portsmouth', 2),
#  ('southampton', 2),
#  ('apr', 2),
#  ('luton', 2),
#  ('congress', 2),
#  ('budget', 2),
#  ('care', 2),
#  ('provis', 2),
#  ('brendan', 2),
#  ('barber', 2),
#  ('frontlin', 2),
#  ('women', 2),
#  ('decent', 2),
#  ('list', 2),
#  ('cubic', 2),
#  ('star', 2),
#  ('confid', 2),
#  ('ball', 2),
#  ('burger', 2),
#  ('champion', 2),
#  ('gordon', 2),
#  ('franc', 2),
#  ('amor', 2),
#  ('vehicl', 2),
#  ('racer', 2),
#  ('leg', 2),
#  ('ampute', 2),
#  ('gearbox', 2),
#  ('rider', 2),
#  ('throttl', 2),
#  ('brake', 2),
#  ('wheel', 2),
#  ('rise', 2),
#  ('peak', 2),
#  ('trough', 2),
#  ('volatil', 2),
#  ('reserv', 2),
#  ('investor', 2),
#  ('price', 2),
#  ('aka', 2),
#  ('sun', 2),
#  ('recoveri', 2),
#  ('payout', 2),
#  ('type', 2),
#  ('pain', 2),
#  ('verdict', 2),
#  ('evid', 2),
#  ('brand', 2),
#  ('name', 2),
#  ('shop', 2),
#  ('shelv', 2),
#  ('battl', 2),
#  ('septemb', 2),
#  ('million', 2),
#  ('dollar', 2),
#  ('litig', 2),
#  ('alarm', 2),
#  ('bell', 2),
#  ('note', 2),
#  ('pfizer', 2),
#  ('user', 2),
#  ('stomach', 2),
#  ('investig', 2),
#  ('announc', 2),
#  ('reintroduct', 2),
#  ('caught', 2),
#  ('surpris', 2),
#  ('head', 2),
#  ('therapi', 2),
#  ('uniqu', 2),
#  ('calcul', 2),
#  ('death', 2),
#  ('stem', 2),
#  ('handl', 2),
#  ('medicin', 2),
#  ('agenc', 2),
#  ('doctor', 2),
#  ('factor', 2),
#  ('pledg', 2),
#  ('chancellor', 2),
#  ('brown', 2),
#  ('vaccin', 2),
#  ('bill', 2),
#  ('foundat', 2),
#  ('gave', 2),
#  ('blair', 2),
#  ('tactic', 2),
#  ('tell', 2),
#  ('someon', 2),
#  ('radio', 2),
#  ('immigr', 2),
#  ('shield', 2),
#  ('wilburn', 2),
#  ('target', 1),
#  ('crackdown', 1),
#  ('ruth', 1),
#  ('initi', 1),
#  ('statist', 1),
#  ('track', 1),
#  ('prosecut', 1),
#  ('holiday', 1),
#  ('classroom', 1),
#  ('remaind', 1),
#  ('improv', 1),
#  ('equival', 1),
#  ('sixth', 1),
#  ('polic', 1),
#  ('welfar', 1),
#  ('hotshot', 1),
#  ('sweep', 1),
#  ('youngster', 1),
#  ('skill', 1),
#  ('sourc', 1),
#  ('count', 1),
#  ('tool', 1),
#  ('fear', 1),
#  ('favour', 1),
#  ('suspicion', 1),
#  ('introduct', 1),
#  ('departur', 1),
#  ('incom', 1),
#  ('member', 1),
#  ('hous', 1),
#  ('welsh', 1),
#  ('mailshot', 1),
#  ('leaflet', 1),
#  ('shift', 1),
#  ('poll', 1),
#  ('happen', 1),
#  ('younger', 1),
#  ('doubt', 1),
#  ('democraci', 1),
#  ('consensu', 1),
#  ('allan', 1),
#  ('medal', 1),
#  ('hurdl', 1),
#  ('madrid', 1),
#  ('learn', 1),
#  ('curv', 1),
#  ('bride', 1),
#  ('sweden', 1),
#  ('robert', 1),
#  ('dudley', 1),
#  ('run', 1),
#  ('heat', 1),
#  ('pix', 1),
#  ('ran', 1),
#  ('clock', 1),
#  ('frontal', 1),
#  ('kind', 1),
#  ('input', 1),
#  ('map', 1),
#  ('scotland', 1),
#  ('centuri', 1),
#  ('element', 1),
#  ('susten', 1),
#  ('tea', 1),
#  ('idea', 1),
#  ('glasgow', 1),
#  ('mercuri', 1),
#  ('singl', 1),
#  ('audienc', 1),
#  ('reid', 1),
#  ('hall', 1),
#  ('rang', 1),
#  ('individu', 1),
#  ('angst', 1),
#  ('mingl', 1),
#  ('scissor', 1),
#  ('sister', 1),
#  ('upbeat', 1),
#  ('smell', 1),
#  ('napalm', 1),
#  ('creativ', 1),
#  ('fellow', 1),
#  ('jame', 1),
#  ('abil', 1),
#  ('edinburgh', 1),
#  ('mikhail', 1),
#  ('gorbachev', 1),
#  ('professor', 1),
#  ('stephen', 1),
#  ('daunt', 1),
#  ('brain', 1),
#  ('tonight', 1),
#  ('entertain', 1),
#  ('venu', 1),
#  ('louder', 1),
#  ('voic', 1),
#  ('megastar', 1),
#  ('album', 1),
#  ('concert', 1),
#  ('demand', 1),
#  ('lotteri', 1),
#  ('opera', 1),
#  ('divers', 1),
#  ('opportun', 1),
#  ('cultur', 1),
#  ('travi', 1),
#  ('good', 1),
#  ('answer', 1),
#  ('passion', 1),
#  ('pay', 1),
#  ('subsidi', 1),
#  ('dream', 1),
#  ('jump', 1),
#  ('posit', 1),
#  ('sponsorship', 1),
#  ('mass', 1),
#  ('thousand', 1),
#  ('thumb', 1),
#  ('use', 1),
#  ('treasuri', 1),
#  ('chariti', 1),
#  ('equip', 1),
#  ('mean', 1),
#  ('extent', 1),
#  ('condit', 1),
#  ('respons', 1),
#  ('mould', 1),
#  ('busi', 1),
#  ('breakthrough', 1),
#  ('act', 1),
#  ('yeah', 1),
#  ('veteran', 1),
#  ('attent', 1),
#  ('fratern', 1),
#  ('merit', 1),
#  ('origin', 1),
#  ('whatsoev', 1),
#  ('pocket', 1),
#  ('pollut', 1),
#  ('avenu', 1),
#  ('solut', 1),
#  ('organ', 1),
#  ('test', 1),
#  ('tiebreak', 1),
#  ('cool', 1),
#  ('style', 1),
#  ('decid', 1),
#  ('tournament', 1),
#  ('rotterdam', 1),
#  ('rhythm', 1),
#  ('serv', 1),
#  ('racket', 1),
#  ('court', 1),
#  ('defeat', 1),
#  ('boost', 1),
#  ('south', 1),
#  ('flanker', 1),
#  ('armi', 1),
#  ('sensat', 1),
#  ('matt', 1),
#  ('gateau', 1),
#  ('jake', 1),
#  ('slam', 1),
#  ('winner', 1),
#  ('beat', 1),
#  ('roll', 1),
#  ('lucio', 1),
#  ('lopez', 1),
#  ('tribut', 1),
#  ('emerg', 1),
#  ('monti', 1),
#  ('rhode', 1),
#  ('cricket', 1),
#  ('career', 1),
#  ('ira', 1),
#  ('moment', 1),
#  ('gloucest', 1),
#  ('tech', 1),
#  ('speed', 1),
#  ('demon', 1),
#  ('organis', 1),
#  ('aspect', 1),
#  ('thank', 1),
#  ('innov', 1),
#  ('grid', 1),
#  ('yesterday', 1),
#  ('gosport', 1),
#  ('new', 1),
#  ('roy', 1),
#  ('derbi', 1),
#  ('changer', 1),
#  ('accid', 1),
#  ('websit', 1),
#  ('foot', 1),
#  ('heath', 1),
#  ('robinson', 1),
#  ('devic', 1),
#  ('sidecar', 1),
#  ('invent', 1),
#  ('zealand', 1),
#  ('reckon', 1),
#  ('save', 1),
#  ('second', 1),
#  ('lap', 1),
#  ('isl', 1),
#  ('result', 1),
#  ('exhibit', 1),
#  ('stand', 1),
#  ('impresa', 1),
#  ('ralli', 1),
#  ('varieti', 1),
#  ('disabl', 1),
#  ('driver', 1),
#  ('lincolnshir', 1),
#  ('hawkin', 1),
#  ('parapleg', 1),
#  ('custom', 1),
#  ('quadripleg', 1),
#  ('woman', 1),
#  ('limb', 1),
#  ('marshal', 1),
#  ('psi', 1),
#  ('subaru', 1),
#  ('duck', 1),
#  ('switch', 1),
#  ('stick', 1),
#  ('ring', 1),
#  ('bar', 1),
#  ('raini', 1),
#  ('tradit', 1),
#  ('father', 1),
#  ('murray', 1),
#  ('formula', 1),
#  ('daughter', 1),
#  ('statur', 1),
#  ('hill', 1),
#  ('climb', 1),
#  ('extens', 1),
#  ('cushion', 1),
#  ('back', 1),
#  ('seat', 1),
#  ('complet', 1),
#  ('balanc', 1),
#  ('column', 1),
#  ('lever', 1),
#  ('marathon', 1),
#  ('drive', 1),
#  ('partner', 1),
#  ('trevor', 1),
#  ('engin', 1),
#  ('morri', 1),
#  ('adapt', 1),
#  ('minut', 1),
#  ('millennium', 1),
#  ('declar', 1),
#  ('goal', 1),
#  ('mortal', 1),
#  ('tour', 1),
#  ('aid', 1),
#  ('gate', 1),
#  ('collater', 1),
#  ('capit', 1),
#  ('thereaft', 1),
#  ('friend', 1),
#  ('movement', 1),
#  ('barrier', 1),
#  ('john', 1),
#  ('hilari', 1),
#  ('rhetor', 1),
#  ('realiti', 1),
#  ('continu', 1),
#  ('privatis', 1),
#  ('jibe', 1),
#  ('michael', 1),
#  ('spring', 1),
#  ('legisl', 1),
#  ('play', 1),
#  ('sake', 1),
#  ('pig', 1),
#  ('environ', 1),
#  ('margaret', 1),
#  ('beckett', 1),
#  ('comment', 1),
#  ('duti', 1),
#  ('judgement', 1),
#  ('behalf', 1),
#  ('chord', 1),
#  ('begin', 1),
#  ('dixon', 1),
#  ('headlin', 1),
#  ('quota', 1),
#  ('focu', 1),
#  ('media', 1),
#  ('coverag', 1),
#  ('cleaner', 1),
#  ('hospit', 1),
#  ('disciplin', 1),
#  ('promis', 1),
#  ('correct', 1),
#  ('curriculum', 1),
#  ('tape', 1),
#  ('appeal', 1),
#  ('activist', 1),
#  ('grandchildren', 1),
#  ('alan', 1),
#  ('vision', 1),
#  ('refer', 1),
#  ('stage', 1)]

# %%
topics = list(map(lambda x: list(map(lambda x: x[0], x[:10])), word_counts))
topics
# Out:
# [['year',
#   'govern',
#   'film',
#   'life',
#   'club',
#   'music',
#   'share',
#   'parti',
#   'money',
#   'drug'],
#  ['technolog',
#   'network',
#   'panda',
#   'sound',
#   'audio',
#   'phone',
#   'world',
#   'research',
#   'game',
#   'reserv'],
#  ['peopl',
#   'law',
#   'terror',
#   'power',
#   'right',
#   'blog',
#   'clark',
#   'hous',
#   'evid',
#   'viru'],
#  ['game',
#   'ireland',
#   'england',
#   'tri',
#   'ball',
#   'compani',
#   'jersey',
#   'coach',
#   'way',
#   'refere'],
#  ['price',
#   'growth',
#   'quarter',
#   'year',
#   'economi',
#   'number',
#   'sequel',
#   'singapor',
#   'hous',
#   'effect'],
#  ['peopl',
#   'film',
#   'ranger',
#   'gorg',
#   'project',
#   'children',
#   'wale',
#   'health',
#   'ferguson',
#   'construct'],
#  ['player',
#   'coach',
#   'connor',
#   'relationship',
#   'kid',
#   'week',
#   'wilkinson',
#   'number',
#   'jimmi',
#   'practic'],
#  ['break',
#   'robinson',
#   'leagu',
#   'dodgson',
#   'england',
#   'winter',
#   'player',
#   'australia',
#   'britain',
#   'premiership'],
#  ['parti',
#   'answer',
#   'lord',
#   'hagu',
#   'goldsmith',
#   'advic',
#   'peopl',
#   'attorney',
#   'call',
#   'rule'],
#  ['telegraph',
#   'journalist',
#   'news',
#   'newspap',
#   'condor',
#   'group',
#   'print',
#   'compani',
#   'corp',
#   'share']]

# %%
labels = tm.predict(sentences, token_lists)

# %%
labels
# Out:
# array([0, 3, 3, 5, 0, 4, 1, 0, 6, 3, 4, 8, 0, 0, 4, 0, 7, 0, 1, 3, 7, 0,
#        0, 3, 9, 9, 6, 5, 2, 2, 0, 1, 0, 0, 1, 4, 4, 6, 0, 0, 4, 3, 4, 6,
#        2, 2, 0, 2, 3, 5, 4, 5, 4, 6, 0, 3, 0, 5, 9, 7, 8, 6, 0, 6, 7, 8,
#        7, 0, 3, 8, 0, 5, 4, 5, 0, 2, 5, 0, 1, 5, 9, 0, 0, 0, 6, 0, 1, 9,
#        1, 0, 2, 9, 7, 5, 5, 2, 7, 0, 8, 8])

# %%
def predict(self, sentences, token_lists, out_of_sample=None):
        """
        Predict topics for new_documents
        """
        # Default as False
        out_of_sample = out_of_sample is not None

        if out_of_sample:
            corpus = [self.dictionary.doc2bow(text) for text in token_lists]
            if self.method != 'LDA':
                vec = self.vectorize(sentences, token_lists)
                print(vec)
        else:
            corpus = self.corpus
            vec = self.vec.get(self.method, None)

        if self.method == "LDA":
            lbs = np.array(list(map(lambda x: sorted(self.ldamodel.get_document_topics(x),
                                                     key=lambda x: x[1], reverse=True)[0][0],
                                    corpus)))
        else:
            lbs = self.cluster_model.predict(vec)
        return lbs

# %%
out_of_sample=None

# %%
out_of_sample = out_of_sample is not None

# %%
out_of_sample
# Out:
# False

# %%
tm.method
# Out:
# 'LDA_BERT'

# %%
vec = tm.vec.get(tm.method, None)

# %%
len(vec)
# Out:
# 100

# %%
len(vec[0])
# Out:
# 32

# %%
def get_coherence(model, token_lists, measure='c_v'):
    """
    Get model coherence from gensim.models.coherencemodel
    :param model: Topic_Model object
    :param token_lists: token lists of docs
    :param topics: topics as top words
    :param measure: coherence metrics
    :return: coherence score
    """
    if model.method == 'LDA':
        cm = CoherenceModel(model=model.ldamodel, texts=token_lists, corpus=model.corpus, dictionary=model.dictionary,
                            coherence=measure)
    else:
        topics = get_topic_words(token_lists, model.cluster_model.labels_)
        cm = CoherenceModel(topics=topics, texts=token_lists, corpus=model.corpus, dictionary=model.dictionary,
                            coherence=measure)
    return cm.get_coherence()

def get_silhouette(model):
    """
    Get silhouette score from model
    :param model: Topic_Model object
    :return: silhouette score
    """
    if model.method == 'LDA':
        return
    lbs = model.cluster_model.labels_
    vec = model.vec[model.method]
    return silhouette_score(vec, lbs)

# %%
c = get_coherence(tm, token_lists, 'c_v')
s = get_silhouette(tm)
print('Number of Topics:', ntopic)
print('Coherence:', c)
print('Silhouette Score:', s)
# Out:
# Number of Topics: 10
# Coherence: 0.45509118401342763
# Silhouette Score: 0.54595

# %%
documents.head()
# Out:
#    index                                           abstract
# 0      1  tv future in the hands of viewers with home th...
# 1      2  worldcom boss  left books alone  former worldc...
# 2      3  tigers wary of farrell  gamble  leicester say ...
# 3      4  yeading face newcastle in fa cup premiership s...
# 4      5  ocean s twelve raids box office ocean s twelve...

# %%
documents.shape
# Out:
# (100, 2)

# %%
predictions = documents.copy()
predictions['topic_no'] = np.NaN

# %%
predictions.head()
# Out:
#    index                                           abstract  topic_no
# 0      1  tv future in the hands of viewers with home th...       NaN
# 1      2  worldcom boss  left books alone  former worldc...       NaN
# 2      3  tigers wary of farrell  gamble  leicester say ...       NaN
# 3      4  yeading face newcastle in fa cup premiership s...       NaN
# 4      5  ocean s twelve raids box office ocean s twelve...       NaN

# %%
idx_in
# Out:
# [40,
#  97,
#  97,
#  54,
#  22,
#  71,
#  44,
#  64,
#  2,
#  19,
#  11,
#  92,
#  38,
#  7,
#  62,
#  43,
#  77,
#  7,
#  44,
#  50,
#  61,
#  45,
#  66,
#  95,
#  60,
#  78,
#  57,
#  87,
#  28,
#  16,
#  3,
#  24,
#  74,
#  22,
#  24,
#  23,
#  71,
#  17,
#  84,
#  74,
#  4,
#  80,
#  42,
#  17,
#  76,
#  68,
#  41,
#  20,
#  50,
#  9,
#  4,
#  87,
#  71,
#  8,
#  84,
#  80,
#  93,
#  91,
#  78,
#  49,
#  85,
#  37,
#  75,
#  17,
#  61,
#  92,
#  49,
#  52,
#  97,
#  55,
#  59,
#  65,
#  96,
#  54,
#  84,
#  20,
#  10,
#  86,
#  44,
#  30,
#  60,
#  64,
#  52,
#  66,
#  8,
#  5,
#  44,
#  83,
#  24,
#  59,
#  28,
#  78,
#  77,
#  48,
#  70,
#  68,
#  61,
#  3,
#  47,
#  85]

# %%
labels
# Out:
# array([0, 3, 3, 5, 0, 4, 1, 0, 6, 3, 4, 8, 0, 0, 4, 0, 7, 0, 1, 3, 7, 0,
#        0, 3, 9, 9, 6, 5, 2, 2, 0, 1, 0, 0, 1, 4, 4, 6, 0, 0, 4, 3, 4, 6,
#        2, 2, 0, 2, 3, 5, 4, 5, 4, 6, 0, 3, 0, 5, 9, 7, 8, 6, 0, 6, 7, 8,
#        7, 0, 3, 8, 0, 5, 4, 5, 0, 2, 5, 0, 1, 5, 9, 0, 0, 0, 6, 0, 1, 9,
#        1, 0, 2, 9, 7, 5, 5, 2, 7, 0, 8, 8])

# %%
count = 0
for idx in idx_in:
    predictions['topic_no'][idx] = labels[count]
    count = count + 1

# %%
predictions.head()
# Out:
#    index                                           abstract  topic_no
# 0      1  tv future in the hands of viewers with home th...       NaN
# 1      2  worldcom boss  left books alone  former worldc...       NaN
# 2      3  tigers wary of farrell  gamble  leicester say ...       6.0
# 3      4  yeading face newcastle in fa cup premiership s...       0.0
# 4      5  ocean s twelve raids box office ocean s twelve...       4.0

# %%
predictions["topic_no"].value_counts()
# Out:
# 0.0    18
# 5.0     9
# 4.0     7
# 3.0     5
# 2.0     5
# 6.0     5
# 8.0     4
# 7.0     3
# 9.0     3
# 1.0     2
# Name: topic_no, dtype: int64

# %%
predictions.isna().sum()
# Out:
# index        0
# abstract     0
# topic_no    39
# dtype: int64

# %%
mapped_predictions = predictions.groupby('topic_no')['abstract'].apply(list)

# %%
mapped_predictions
# Out:
# topic_no
# 0.0    [yeading face newcastle in fa cup premiership ...
# 1.0    [mobile audio enters new dimension as mobile p...
# 2.0    [howard backs stem cell research michael howar...
# 3.0    [games maker fights for survival one of britai...
# 4.0    [ocean s twelve raids box office ocean s twelv...
# 5.0    [last star wars  not for children  the sixth a...
# 6.0    [tigers wary of farrell  gamble  leicester say...
# 7.0    [stock market eyes japan recovery japanese sha...
# 8.0    [campaign  cold calls  questioned labour and t...
# 9.0    [telegraph newspapers axe 90 jobs the daily an...
# Name: abstract, dtype: object

# %%
mapped_predictions = mapped_predictions.reset_index()
mapped_predictions['keywords_list'] = topics

# %%
mapped_predictions.head()
# Out:
#    topic_no                                           abstract  \
# 0       0.0  [yeading face newcastle in fa cup premiership ...
# 1       1.0  [mobile audio enters new dimension as mobile p...
# 2       2.0  [howard backs stem cell research michael howar...
# 3       3.0  [games maker fights for survival one of britai...
# 4       4.0  [ocean s twelve raids box office ocean s twelv...
#
#                                        keywords_list
# 0  [year, govern, film, life, club, music, share,...
# 1  [technolog, network, panda, sound, audio, phon...
# 2  [peopl, law, terror, power, right, blog, clark...
# 3  [game, ireland, england, tri, ball, compani, j...
# 4  [price, growth, quarter, year, economi, number...

# %%
len(topics)
# Out:
# 10
